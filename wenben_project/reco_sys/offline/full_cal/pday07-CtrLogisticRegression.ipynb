# %%
import os
import sys
# 如果当前代码文件运行测试需要加入修改路径，避免出现后导包问题
BASE_DIR = os.path.dirname(os.path.dirname(os.getcwd()))
sys.path.insert(0, os.path.join(BASE_DIR))

PYSPARK_PYTHON = "/miniconda2/envs/reco_sys/bin/python"
# 当存在多个版本时，不指定很可能会导致出错
os.environ["PYSPARK_PYTHON"] = PYSPARK_PYTHON
os.environ["PYSPARK_DRIVER_PYTHON"] = PYSPARK_PYTHON

from pyspark.ml.feature import OneHotEncoder
from pyspark.ml.feature import StringIndexer
from pyspark.ml import Pipeline
from pyspark.sql.types import *
from pyspark.ml.feature import VectorAssembler
from pyspark.ml.classification import LogisticRegression
from pyspark.ml.classification import LogisticRegressionModel
from offline import SparkSessionBase

class CtrLogisticRegression(SparkSessionBase):

    SPARK_APP_NAME = "ctrLogisticRegression"
    ENABLE_HIVE_SUPPORT = True

    def __init__(self):

        self.spark = self._create_spark_hbase()

ctr = CtrLogisticRegression()

# %%
ctr.spark.sql("use profile")
# +-------------------+----------+----------+-------+
# |            user_id|article_id|channel_id|clicked|
# +-------------------+----------+----------+-------+
# |1105045287866466304|     14225|         0|  false|
user_article_basic = ctr.spark.sql("select * from user_article_basic").select(
    ['user_id', 'article_id', 'channel_id', 'clicked'])

# %%
user_article_basic.show()
# Out:
# +-------------------+----------+----------+-------+
# |            user_id|article_id|channel_id|clicked|
# +-------------------+----------+----------+-------+
# |1105045287866466304|     14225|         0|  false|
# |1106476833370537984|     14208|         0|  false|
# |1111189494544990208|     19322|         0|  false|
# |1111524501104885760|     44161|         0|  false|
# |1112727762809913344|     18172|        18|   true|
# |                  1|     44386|        18|   true|
# |                  1|     44696|         0|  false|
# |                 10|     43907|         0|  false|
# |1106473203766657024|     16005|         0|  false|
# |1108264901190615040|     15196|         0|  false|
# |                 23|     44739|        18|   true|
# |                 33|     13570|         0|  false|
# |                  1|     17632|         0|  false|
# |1106473203766657024|     17665|         0|  false|
# |1111189494544990208|     44368|         0|  false|
# |                 10|     44368|         0|  false|
# |1105093883106164736|     15750|         0|  false|
# |1106396183141548032|     19476|         0|  false|
# |1111524501104885760|     19233|         0|  false|
# |                  2|     44371|        18|   true|
# +-------------------+----------+----------+-------+
# only showing top 20 rows

# %% [markdown]
# ### 用户画像读取处理与日志数据合并

# %%
user_profile_hbase = ctr.spark.sql(
    "select user_id, information.birthday, information.gender, article_partial, env from user_profile_hbase")
user_profile_hbase = user_profile_hbase.drop('env')

# +--------------------+--------+------+--------------------+
# |             user_id|birthday|gender|     article_partial|
# +--------------------+--------+------+--------------------+
# |              user:1|     0.0|  null|Map(18:Animal -> ...|

_schema = StructType([
    StructField("user_id", LongType()),
    StructField("birthday", DoubleType()),
    StructField("gender", BooleanType()),
    StructField("weights", MapType(StringType(), DoubleType()))
])

def get_user_id(row):
    return int(row.user_id.split(":")[1]), row.birthday, row.gender, row.article_partial

# %%
user_profile_hbase_temp = user_profile_hbase.rdd.map(get_user_id)
user_profile_hbase_schema = ctr.spark.createDataFrame(user_profile_hbase_temp, schema=_schema)

# %%
train = user_article_basic.join(user_profile_hbase_schema, on=['user_id'], how='left').drop('channel_id')

# %%
train.show()
# Out:
# +-------------------+----------+-------+--------+------+--------------------+
# |            user_id|article_id|clicked|birthday|gender|             weights|
# +-------------------+----------+-------+--------+------+--------------------+
# |1106473203766657024|     16005|  false|     0.0|  null|Map(18:text -> 0....|
# |1106473203766657024|     17665|  false|     0.0|  null|Map(18:text -> 0....|
# |1106473203766657024|     44664|  false|     0.0|  null|Map(18:text -> 0....|
# |1106473203766657024|     44386|  false|     0.0|  null|Map(18:text -> 0....|
# |1106473203766657024|     13778|  false|     0.0|  null|Map(18:text -> 0....|
# |1106473203766657024|     13039|  false|     0.0|  null|Map(18:text -> 0....|
# |1106473203766657024|     13648|  false|     0.0|  null|Map(18:text -> 0....|
# |1106473203766657024|     17304|  false|     0.0|  null|Map(18:text -> 0....|
# |1106473203766657024|     19233|  false|     0.0|  null|Map(18:text -> 0....|
# |1106473203766657024|     44466|  false|     0.0|  null|Map(18:text -> 0....|
# |1106473203766657024|     18795|  false|     0.0|  null|Map(18:text -> 0....|
# |1106473203766657024|    134812|  false|     0.0|  null|Map(18:text -> 0....|
# |1106473203766657024|     13357|  false|     0.0|  null|Map(18:text -> 0....|
# |1106473203766657024|     19171|  false|     0.0|  null|Map(18:text -> 0....|
# |1106473203766657024|     44104|  false|     0.0|  null|Map(18:text -> 0....|
# |1106473203766657024|     13340|  false|     0.0|  null|Map(18:text -> 0....|
# |1106473203766657024|     14225|  false|     0.0|  null|Map(18:text -> 0....|
# |1106473203766657024|     44739|  false|     0.0|  null|Map(18:text -> 0....|
# |1106473203766657024|     19016|  false|     0.0|  null|Map(18:text -> 0....|
# |1106473203766657024|    136500|  false|     0.0|  null|Map(18:text -> 0....|
# +-------------------+----------+-------+--------+------+--------------------+
# only showing top 20 rows

# %% [markdown]
# ### 文章向量读取&合并

# %%
ctr.spark.sql("use article")
article_vector = ctr.spark.sql("select * from article_vector")
train = train.join(article_vector, on=['article_id'], how='left').drop('birthday').drop('gender')

# %%
train.show()
# Out:
# +-------------------+-------------------+-------+--------------------+----------+--------------------+
# |         article_id|            user_id|clicked|             weights|channel_id|       articlevector|
# +-------------------+-------------------+-------+--------------------+----------+--------------------+
# |              13401|                 10|  false|Map(18:tp2 -> 0.1...|        18|[0.06157120217893...|
# |              13401|1106396183141548032|  false|Map(18:tp2 -> 0.1...|        18|[0.06157120217893...|
# |              14805|1106473203766657024|  false|Map(18:text -> 0....|        18|[0.11028526511434...|
# |              14805|1103195673450250240|  false|Map(18:Animal -> ...|        18|[0.11028526511434...|
# |              14805|1105045287866466304|  false|Map(18:text -> 0....|        18|[0.11028526511434...|
# |              14805|1111524501104885760|  false|Map(18:text -> 0....|        18|[0.11028526511434...|
# |              14805|1105105185656537088|  false|Map(18:SHOldboySt...|        18|[0.11028526511434...|
# |              14805|                  1|  false|Map(18:Animal -> ...|        18|[0.11028526511434...|
# |              14805|                 10|  false|Map(18:tp2 -> 0.1...|        18|[0.11028526511434...|
# |              14805|1112727762809913344|  false|Map(18:text -> 0....|        18|[0.11028526511434...|
# |              14805|                  2|   true|Map(18:obj3 -> 0....|        18|[0.11028526511434...|
# |              14805|1106396183141548032|  false|Map(18:tp2 -> 0.1...|        18|[0.11028526511434...|
# |              14805|1106476833370537984|  false|Map(18:text -> 1....|        18|[0.11028526511434...|
# |              14805|                 38|  false|Map(18:结构化 -> 0.1...|        18|[0.11028526511434...|
# |              14805|                 23|  false|Map(18:结构化 -> 0.1...|        18|[0.11028526511434...|
# |              14805|1108264901190615040|  false|Map(18:text -> 0....|        18|[0.11028526511434...|
# |              14805|1111189494544990208|  false|Map(18:text -> 0....|        18|[0.11028526511434...|
# |1112593324574769152|1113316420155867136|  false|                null|      null|                null|
# |1112593324574769152|1113244157343694848|  false|Map(18:text -> 0....|      null|                null|
# |              44013|1103195673450250240|  false|Map(18:Animal -> ...|        18|[0.13236314698992...|
# +-------------------+-------------------+-------+--------------------+----------+--------------------+
# only showing top 20 rows

# %%
### 合并文章画像权重特征
ctr.spark.sql("use article")
article_profile = ctr.spark.sql("select * from article_profile")

# %%
def article_profile_to_feature(row):

    try:
        weights = sorted(row.keywords.values())[:10]
    except Exception as e:
        weights = [0.0] * 10
    return row.article_id, weights
article_profile = article_profile.rdd.map(article_profile_to_feature).toDF(['article_id', 'article_weights'])

train = train.join(article_profile, on=['article_id'], how='left')

# %%
train.show()
# Out:
# +-------------------+-------------------+-------+--------------------+----------+--------------------+--------------------+
# |         article_id|            user_id|clicked|             weights|channel_id|       articlevector|     article_weights|
# +-------------------+-------------------+-------+--------------------+----------+--------------------+--------------------+
# |              13401|                 10|  false|Map(18:tp2 -> 0.1...|        18|[0.06157120217893...|[0.08196639249252...|
# |              13401|1106396183141548032|  false|Map(18:tp2 -> 0.1...|        18|[0.06157120217893...|[0.08196639249252...|
# |              14805|1106473203766657024|  false|Map(18:text -> 0....|        18|[0.11028526511434...|[0.15069781969741...|
# |              14805|1103195673450250240|  false|Map(18:Animal -> ...|        18|[0.11028526511434...|[0.15069781969741...|
# |              14805|1105045287866466304|  false|Map(18:text -> 0....|        18|[0.11028526511434...|[0.15069781969741...|
# |              14805|1111524501104885760|  false|Map(18:text -> 0....|        18|[0.11028526511434...|[0.15069781969741...|
# |              14805|1105105185656537088|  false|Map(18:SHOldboySt...|        18|[0.11028526511434...|[0.15069781969741...|
# |              14805|                  1|  false|Map(18:Animal -> ...|        18|[0.11028526511434...|[0.15069781969741...|
# |              14805|                 10|  false|Map(18:tp2 -> 0.1...|        18|[0.11028526511434...|[0.15069781969741...|
# |              14805|1112727762809913344|  false|Map(18:text -> 0....|        18|[0.11028526511434...|[0.15069781969741...|
# |              14805|                  2|   true|Map(18:obj3 -> 0....|        18|[0.11028526511434...|[0.15069781969741...|
# |              14805|1106396183141548032|  false|Map(18:tp2 -> 0.1...|        18|[0.11028526511434...|[0.15069781969741...|
# |              14805|1106476833370537984|  false|Map(18:text -> 1....|        18|[0.11028526511434...|[0.15069781969741...|
# |              14805|                 38|  false|Map(18:结构化 -> 0.1...|        18|[0.11028526511434...|[0.15069781969741...|
# |              14805|                 23|  false|Map(18:结构化 -> 0.1...|        18|[0.11028526511434...|[0.15069781969741...|
# |              14805|1108264901190615040|  false|Map(18:text -> 0....|        18|[0.11028526511434...|[0.15069781969741...|
# |              14805|1111189494544990208|  false|Map(18:text -> 0....|        18|[0.11028526511434...|[0.15069781969741...|
# |1112593324574769152|1113316420155867136|  false|                null|      null|                null|                null|
# |1112593324574769152|1113244157343694848|  false|Map(18:text -> 0....|      null|                null|                null|
# |              44013|1103195673450250240|  false|Map(18:Animal -> ...|        18|[0.13236314698992...|[0.10139833833795...|
# +-------------------+-------------------+-------+--------------------+----------+--------------------+--------------------+
# only showing top 20 rows

# %%
train.rdd.take(1)
# Out:
# [Row(article_id=13401, user_id=10, clicked=False, weights={'18:有序': 0.14441985236498525, '18:symmetric': 0.1441433918957283, '18:prd': 0.1441433918957283, '18:address': 0.1441433918957283, '18:转义字符': 0.1441433918957283, '18:numb': 0.14441985236498525, '18:cquire': 0.1441433918957283, '18:lis': 0.1441433918957283, '18:ceng': 0.14441985236498525, '18:encoding': 0.1441433918957283, '18:chouti': 0.14441985236498525, '18:语音合成': 0.1441433918957283, '18:Requests': 0.1441433918957283, '18:wusir': 0.1441433918957283, '18:session': 0.1441433918957283, '18:host': 0.1441433918957283, '18:sort': 0.14441985236498525, '18:代码自动补全': 1.2972905270615547, '18:popitem': 0.1441433918957283, '18:鸡蛋': 0.1441433918957283, '18:ida': 0.145755889693766, '18:collections': 0.1441433918957283, '18:finally': 0.1441433918957283, '18:queue': 0.1441433918957283, '18:布尔值': 0.1441433918957283, '18:urlretrieve': 0.1441433918957283, '18:lambda': 0.1441433918957283, '18:implicit': 0.1441433918957283, '18:ImageFont': 0.1441433918957283, '18:whyz': 0.1441433918957283, '18:异构': 0.14441985236498525, '18:find': 0.1441433918957283, '18:counts': 0.1441433918957283, '18:sys': 0.1441433918957283, '18:+++': 0.1441433918957283, '18:用法': 0.1441433918957283, '18:&#': 0.14441985236498525, '18:基数': 0.1441433918957283, '18:audio': 0.1441433918957283, '18:arr': 0.1441433918957283, '18:headers': 0.1441433918957283, '18:key': 0.1441433918957283, '18:create': 0.1441433918957283, '18:增删改': 0.1441433918957283, '18:Python': 0.1441433918957283, '18:迭代器': 0.1441433918957283, '18:letter': 0.1441433918957283, '18:arg': 0.1441433918957283, '18:requests': 0.1441433918957283, '18:txt': 0.1441433918957283, '18:escape': 0.1441433918957283, '18:bytes': 0.1441433918957283, '18:#&': 0.1441433918957283, '18:匿名函数': 0.1441433918957283, '18:周杰伦': 0.1441433918957283, '18:forms': 0.1441433918957283, '18:maxconn': 0.1441433918957283, '18:##': 0.1441433918957283, '18:代指': 0.1441433918957283, '18:percent': 0.1441433918957283, '18:keys': 0.1441433918957283, '18:原值': 0.1441433918957283, '18:houdini': 1.2972905270615547, '18:query': 0.1441433918957283, '18:Advanced': 0.1441433918957283, '18:mess': 0.1441433918957283, '18:元祖': 0.1441433918957283, '18:lst1': 0.1441433918957283, '18:alexsel': 0.1441433918957283, '18:myStr': 0.1441433918957283, '18:collect': 0.1441433918957283, '18:stats': 0.1441433918957283, '18:sequence': 0.1441433918957283, '18:lst2': 0.1441433918957283, '18:weight': 0.1441433918957283, '18:isalnum': 0.1441433918957283, '18:mktime': 0.1441433918957283, '18:app': 0.1441433918957283, '18:Tang': 0.1441433918957283, '18:jay': 0.1441433918957283, '18:fruits': 0.1441433918957283, '18:八进制': 0.1441433918957283, '18:state': 0.1441433918957283, '18:contrib': 0.1441433918957283, '18:male': 0.14441985236498525, '18:FOREGROUND': 0.1441433918957283, '18:render': 0.1441433918957283, '18:类方法': 0.1441433918957283, '18:HEIGHT': 0.1441433918957283, '18:obj2': 0.1441433918957283, '18:len': 0.1441433918957283, '18:xiaoming': 0.1441433918957283, '18:author': 0.1441433918957283, '18:str': 0.1441433918957283, '18:java': 0.1441433918957283, '18:creditcard': 0.1441433918957283, '18:lineInfo': 0.1441433918957283, '18:insert': 0.1441433918957283, '18:ffmpeg': 0.1441433918957283, '18:ste': 0.1441433918957283, '18:环境变量': 0.1441433918957283, '18:成员': 0.1441433918957283, '18:register': 0.1441433918957283, '18:KEY': 0.1441433918957283, '18:文件夹': 0.1441433918957283, '18:Simple': 0.1441433918957283, '18:Good': 0.1441433918957283, '18:fillchar': 0.1441433918957283, '18:MongoClient': 0.1441433918957283, '18:元素': 0.1441433918957283, '18:subn': 0.1441433918957283, '18:outer': 0.1441433918957283, '18:stu': 0.1441433918957283, '18:args': 0.1441433918957283, '18:pop': 0.1441433918957283, '18:min': 0.1441433918957283, '18:补码': 0.1441433918957283, '18:start': 0.1441433918957283, '18:difference': 0.14441985236498525, '18:delete': 0.1441433918957283, '18:sum': 0.1441433918957283, '18:商品': 0.14441985236498525, '18:负数': 0.1441433918957283, '18 ...

# %% [markdown]
# ### 处理用户画像权重

# %%
columns = ['article_id', 'user_id', 'channel_id', 'articlevector', 'user_weights', 'article_weights', 'clicked']
def get_user_weights(row):

    from pyspark.ml.linalg import Vectors
    try:
        user_weights = sorted([row.article_partial[key] for key in row.article_partial.keys() if key.split(':')[0] == str(row.channel_id)])[
                  :10]
    except Exception:
        user_weights = [0.0] * 10

    return row.article_id, row.user_id, row.channel_id, Vectors.dense(row.articlevector), Vectors.dense(
        user_weights), Vectors.dense(row.article_weights), int(row.clicked)

train_vector = train.rdd.map(get_user_weights).toDF(columns)

# %%
train_vector = train_vector.dropna()

# %%
train_version_two = VectorAssembler().setInputCols(columns[2:6]).setOutputCol("features").transform(train_vector)

# %%
train_dataset, test_dataset = train_version_two.randomSplit([0.8, 0.2])

# %%
### 训练模型
lr = LogisticRegression()
model = lr.setLabelCol("clicked").setFeaturesCol("features").fit(train_dataset)

# %% [markdown]
# ## 点击率预测结果

# %%
online_model = LogisticRegressionModel.load('/headlines/models/logistic_ctr_model.obj')

# %%
res_transfrom = online_model.transform(test_dataset)

# %%
res_transfrom.select(["clicked", "probability", "prediction"]).show()
# Out:
# +-------+--------------------+----------+
# |clicked|         probability|prediction|
# +-------+--------------------+----------+
# |      0|[0.89423045678107...|       0.0|
# |      0|[0.89423045678107...|       0.0|
# |      0|[0.89426978371863...|       0.0|
# |      0|[0.89426450318935...|       0.0|
# |      0|[0.89426450318935...|       0.0|
# |      0|[0.89436330452490...|       0.0|
# |      0|[0.89437568953445...|       0.0|
# |      0|[0.89441205607391...|       0.0|
# |      0|[0.89440179073518...|       0.0|
# |      0|[0.89440179073518...|       0.0|
# |      0|[0.89431388412402...|       0.0|
# |      0|[0.89431388412402...|       0.0|
# |      0|[0.89431388412402...|       0.0|
# |      0|[0.89431682922322...|       0.0|
# |      0|[0.89438068510966...|       0.0|
# |      0|[0.89433063939791...|       0.0|
# |      0|[0.89436206744987...|       0.0|
# |      0|[0.89433503039271...|       0.0|
# |      0|[0.89433503039271...|       0.0|
# |      0|[0.89436484089326...|       0.0|
# +-------+--------------------+----------+
# only showing top 20 rows

# %%
def vector_to_double(row):
    return float(row.clicked), float(row.probability[1]) 

score_label = res_transfrom.select(["clicked", "probability"]).rdd.map(vector_to_double)

# %%
score_label.collect()
# Out:
# [(0.0, 0.10576954321892673),
#  (0.0, 0.10576954321892673),
#  (0.0, 0.10573021628136077),
#  (0.0, 0.10573549681064946),
#  (0.0, 0.10573549681064946),
#  (0.0, 0.10563669547509504),
#  (0.0, 0.10562431046554033),
#  (0.0, 0.10558794392608098),
#  (0.0, 0.10559820926481729),
#  (0.0, 0.10559820926481729),
#  (0.0, 0.1056861158759755),
#  (0.0, 0.1056861158759755),
#  (0.0, 0.1056861158759755),
#  (0.0, 0.10568317077677611),
#  (0.0, 0.105619314890337),
#  (0.0, 0.1056693606020893),
#  (0.0, 0.10563793255012317),
#  (0.0, 0.1056649696072864),
#  (0.0, 0.1056649696072864),
#  (0.0, 0.10563515910673836),
#  (0.0, 0.10560590876054553),
#  (0.0, 0.10568620505244941),
#  (0.0, 0.10568620505244941),
#  (0.0, 0.10568620505244941),
#  (0.0, 0.10562974738174792),
#  (0.0, 0.1054320752404753),
#  (0.0, 0.1054320752404753),
#  (0.0, 0.10585358794457175),
#  (0.0, 0.10585358794457175),
#  (0.0, 0.10585358794457175),
#  (0.0, 0.10577854573252297),
#  (1.0, 0.10563120791722667),
#  (0.0, 0.10563120791722667),
#  (0.0, 0.10563120791722667),
#  (0.0, 0.10563120791722667),
#  (0.0, 0.10570345488501834),
#  (0.0, 0.10562165962046205),
#  (1.0, 0.10562165962046205),
#  (0.0, 0.10562165962046205),
#  (0.0, 0.10568083213870363),
#  (0.0, 0.10557097909745132),
#  (0.0, 0.10565515549972274),
#  (0.0, 0.10560882806429389),
#  (0.0, 0.10560882806429389),
#  (0.0, 0.10574080519386847),
#  (0.0, 0.1056831767957044),
#  (0.0, 0.10564591619088896),
#  (0.0, 0.10564591619088896),
#  (0.0, 0.10564591619088896),
#  (0.0, 0.10563139993552044),
#  (0.0, 0.10570154705084038),
#  (0.0, 0.10570154705084038),
#  (1.0, 0.10570154705084038),
#  (1.0, 0.10570154705084038),
#  (1.0, 0.10570154705084038),
#  (1.0, 0.10570154705084038),
#  (0.0, 0.10564801679407733),
#  (1.0, 0.10574130474498336),
#  (1.0, 0.10563442629587749),
#  (0.0, 0.10563558838976528),
#  (0.0, 0.10563558838976528),
#  (0.0, 0.10563558838976528),
#  (0.0, 0.10563558838976528),
#  (0.0, 0.10563558838976528),
#  (1.0, 0.10565493755704523),
#  (0.0, 0.10565493755704523),
#  (0.0, 0.10561991626355723),
#  (0.0, 0.10561991626355723),
#  (0.0, 0.10561991626355723),
#  (0.0, 0.10567296065010362),
#  (0.0, 0.10567296065010362),
#  (0.0, 0.10562516275356895),
#  (0.0, 0.10562516275356895),
#  (1.0, 0.10572568306841196),
#  (0.0, 0.10572568306841196),
#  (0.0, 0.10572568306841196),
#  (0.0, 0.10572568306841196),
#  (0.0, 0.10561085164164351),
#  (0.0, 0.10561085164164351),
#  (0.0, 0.10568611792497631),
#  (0.0, 0.10568611792497631),
#  (0.0, 0.10568611792497631),
#  (0.0, 0.10568611792497631),
#  (0.0, 0.10568611792497631),
#  (0.0, 0.105680465456784),
#  (0.0, 0.105680465456784),
#  (0.0, 0.105680465456784),
#  (0.0, 0.10565110710506515),
#  (0.0, 0.10577176620395265),
#  (0.0, 0.10571184914779108),
#  (0.0, 0.10571215539568618),
#  (0.0, 0.10566515232420669),
#  (0.0, 0.10566515232420669),
#  (0.0, 0.10566515232420669),
#  (0.0, 0.10568502583952295),
#  (0.0, 0.10563146547114194),
#  (0.0, 0.10563146547114194),
#  (0.0, 0.10567314891542018),
#  (0.0, 0.10564864313235943),
#  (0.0, 0.10567867810939109),
#  (0.0, 0.10570453533045825),
#  (0.0, 0.10573009009184876),
#  (0.0, 0.1056174014105133),
#  (0.0, 0.10566239952278796),
#  (0.0, 0.10567261030940005),
#  (1.0, 0.10567196056965417),
#  (1.0, 0.10570670331703923),
#  (0.0, 0.10570670331703923),
#  (0.0, 0.10570670331703923),
#  (0.0, 0.10570670331703923),
#  (0.0, 0.10570670331703923),
#  (0.0, 0.10540891589448113),
#  (0.0, 0.10540891589448113),
#  (0.0, 0.10540891589448113),
#  (0.0, 0.10540891589448113),
#  (0.0, 0.10582159808897627),
#  (0.0, 0.10553575178744029),
#  (0.0, 0.10566859599196368),
#  (0.0, 0.10566859599196368),
#  (0.0, 0.10566859599196368),
#  (1.0, 0.10569083847767109),
#  (0.0, 0.10568141230706458),
#  (0.0, 0.10563752730783062),
#  (0.0, 0.10568466623032291),
#  (0.0, 0.10580057084230066),
#  (0.0, 0.10580057084230066),
#  (0.0, 0.10568504490926577),
#  (0.0, 0.10561748012200059),
#  (0.0, 0.10561748012200059),
#  (0.0, 0.10561748012200059),
#  (0.0, 0.10561748012200059),
#  (0.0, 0.10567827107822364),
#  (0.0, 0.10567827107822364),
#  (0.0, 0.10567827107822364),
#  (0.0, 0.10571526283096287),
#  (0.0, 0.10568642815680539),
#  (0.0, 0.1057736991425509),
#  (0.0, 0.1057736991425509),
#  (0.0, 0.10570170840655878),
#  (0.0, 0.10565124825708641),
#  (1.0, 0.10559845245051454),
#  (0.0, 0.10568887727354455),
#  (0.0, 0.10569461067166676),
#  (0.0, 0.1057283921487371),
#  (0.0, 0.10564989504125807),
#  (0.0, 0.1055875182232719),
#  (0.0, 0.1055875182232719),
#  (0.0, 0.10570810305109797),
#  (0.0, 0.10564960879074617),
#  (1.0, 0.10576903196944477),
#  (0.0, 0.10576903196944477),
#  (0.0, 0.10576903196944477),
#  (0.0, 0.10576903196944477),
#  (0.0, 0.10576903196944477),
#  (0.0, 0.10576903196944477),
#  (0.0, 0.10560506876075149),
#  (0.0, 0.10564391318146399),
#  (0.0, 0.10562932238724594),
#  (0.0, 0.10562932238724594),
#  (0.0, 0.1056049286433147),
#  (0.0, 0.1056049286433147),
#  (0.0, 0.1056049286433147),
#  (0.0, 0.1056049286433147),
#  (0.0, 0.10564892190531473),
#  (0.0, 0.10564892190531473),
#  (0.0, 0.10564892190531473),
#  (0.0, 0.10564892190531473),
#  (0.0, 0.10567870113846822),
#  (0.0, 0.10569432160984252),
#  (0.0, 0.10550047001132876),
#  (0.0, 0.10550047001132876),
#  (0.0, 0.10568086977454504),
#  (0.0, 0.10567133100268078),
#  (0.0, 0.10568880955013006),
#  (0.0, 0.10564652305360592),
#  (0.0, 0.10579892372369008),
#  (0.0, 0.10579892372369008),
#  (0.0, 0.10579892372369008),
#  (0.0, 0.10579892372369008),
#  (0.0, 0.10564952859664822),
#  (0.0, 0.10566993616106142),
#  (0.0, 0.1057902458184062),
#  (0.0, 0.10558892079687032),
#  (0.0, 0.1057344152497768),
#  (0.0, 0.10567458448808591),
#  (0.0, 0.10575421881155997),
#  (0.0, 0.10575421881155997),
#  (0.0, 0.10561872276881011),
#  (0.0, 0.10561872276881011),
#  (0.0, 0.10561872276881011),
#  (0.0, 0.10561872276881011),
#  (0.0, 0.1057360950202556),
#  (0.0, 0.1057360950202556),
#  (0.0, 0.10576702720256621),
#  (0.0, 0.10566520353231822),
#  (0.0, 0.10566520353231822),
#  (1.0, 0.10566520353231822)]
