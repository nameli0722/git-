# %%
import os
import sys
# 如果当前代码文件运行测试需要加入修改路径，避免出现后导包问题
BASE_DIR = os.path.dirname(os.path.dirname(os.getcwd()))
sys.path.insert(0, os.path.join(BASE_DIR))
PYSPARK_PYTHON = "/miniconda2/envs/reco_sys/bin/python"
# 当存在多个版本时，不指定很可能会导致出错
os.environ["PYSPARK_PYTHON"] = PYSPARK_PYTHON
os.environ["PYSPARK_DRIVER_PYTHON"] = PYSPARK_PYTHON
from offline import SparkSessionBase

class KeywordsToTfidf(SparkSessionBase):

    SPARK_APP_NAME = "keywordsByTFIDF"
    #SPARK_EXECUTOR_MEMORY = "7g"

    ENABLE_HIVE_SUPPORT = True

    def __init__(self):
        self.spark = self._create_spark_session()

# %%
ktt = KeywordsToTfidf()

# %%
ktt.spark.sql("use article")
article_dataframe = ktt.spark.sql("select * from article_data limit 20")

# %%
article_dataframe.show()
# Out:
# +----------+----------+------------+--------------------+--------------------+--------------------+
# |article_id|channel_id|channel_name|               title|             content|            sentence|
# +----------+----------+------------+--------------------+--------------------+--------------------+
# |         1|        17|          前端|     Vue props用法小结原荐|<p><strong>Vue pr...|前端,Vue props用法小结原...|
# |         2|        17|          前端|vue.js响应式原理解析与实现—...|<p>上次我们已经分析了vue.j...|前端,vue.js响应式原理解析与...|
# |         3|        17|          前端|JavaScript中浅拷贝和深拷...|<p>要理解 JavaScript...|前端,JavaScript中浅拷贝...|
# |         4|        17|          前端|基于vue2.0 +vuex+ e...|<p>效果演示地址,</p><p>...|前端,基于vue2.0 +vuex...|
# |         5|        17|          前端|immutability因Reac...|<p><img src="http...|前端,immutability因R...|
# |         6|        17|          前端|简单了解 node npm cnp...|<span id="OSC_h1_...|前端,简单了解 node npm ...|
# |         7|        17|          前端|       Web工程师以太坊入门原荐|<p>我经常构建使用以太坊的Web...|前端,Web工程师以太坊入门原荐,...|
# |         8|        17|          前端|Webpack 4 api 了解与...|<h2>webpack 最近升级到...|前端,Webpack 4 api ...|
# |         9|        17|          前端|vue中用数据驱动视图的思想去写代...|<h4>前言</h4><p>如何在...|前端,vue中用数据驱动视图的思想...|
# |        10|        17|          前端|微信小程序中如何使用WebSock...|<p>本文由腾讯云技术团队原创，感...|前端,微信小程序中如何使用WebS...|
# |        11|        17|          前端|flux架构，是我理解错了吗？记一...|<h1>flux架构，是我理解错了...|前端,flux架构，是我理解错了吗...|
# |        12|        17|          前端|合格前端第十二弹-TypeScri...|<h2>写在前面</h2><p>T...|前端,合格前端第十二弹-TypeS...|
# |        13|        17|          前端|打造专属插件之Easy Slide...|<p><img height="7...|前端,打造专属插件之Easy Sl...|
# |        14|        17|          前端|前后端分离实践：基于vue实现网站...|<blockquote><p><s...|前端,前后端分离实践：基于vue实...|
# |        15|        17|          前端|js异步ajax实现避免页面重复提交原荐|<h3>1 ajax概述</h3>...|前端,js异步ajax实现避免页面...|
# |        17|        17|          前端|JSsearch实现在购物网站输入...|<p>在篇文章里，我们主要讲解一下...|前端,JSsearch实现在购物网...|
# |        18|        17|          前端|从零开始搭建webpack+rea...|<h2>环境主要依赖版本</h2>...|前端,从零开始搭建webpack+...|
# |        19|        17|          前端|合格前端系列第九弹-前端面试那些事顶原荐|<h2>项目相关</h2><ol>...|前端,合格前端系列第九弹-前端面试...|
# |        20|        17|          前端| 总结几个关于 jQuery 用法顶原荐|<h4>有关 jquery 用法<...|前端,总结几个关于 jQuery ...|
# |        21|        17|          前端|为Bootstrap Modal添...|<p>        网上有许多给...|前端,为Bootstrap Mod...|
# +----------+----------+------------+--------------------+--------------------+--------------------+

# %%
article_dataframe.rdd.take(1)
# Out:
# [Row(article_id=1, channel_id=17, channel_name='前端', title='Vue props用法小结原荐', content='<p><strong>Vue props用法详解</strong>组件接受的选项之一 props 是 Vue 中非常重要的一个选项。父子组件的关系可以总结为：</p><p><code>props down, events up</code></p><p>父组件通过 props 向下传递数据给子组件；子组件通过 events 给父组件发送消息。</p><p><strong>父子级组件</strong>比如我们需要创建两个组件 parent 和 child。需要保证每个组件可以在相对隔离的环境中书写，这样也能提高组件的可维护性。</p><p>这里我们先定义父子两个组件和一个 Vue 对象：</p><pre><code>var childNode = { template: `    &lt;div&gt;childNode&lt;/div&gt;    `};var parentNode = { template: `    &lt;div&gt;     &lt;child&gt;&lt;/child&gt;     &lt;child&gt;&lt;/child&gt;    &lt;/div&gt;    `, components: {  child: childNode }//前端全栈学习交流圈：866109386};//帮助1-3Ian前端人员，突破技术瓶颈，提升思维能力new Vue({ el: "#example", components: {  parent: parentNode }});</code></pre><pre><code>&lt;div id="example"&gt; &lt;parent&gt;&lt;/parent&gt;&lt;/div&gt;</code></pre><p>这里的 childNode 定义的 template 是一个 div，并且内容是"childNode"字符串。而在 parentNode 的 template 中定义了 div 的 class 名叫 parent 并且包含了两个 child 组件。</p><p><strong>静态 props</strong>组件实例的作用域是孤立的。这意味着不能（也不应该）在子组件的模板中直接饮用父组件的数据。要让子组件使用父组件的数据，需要通过子组件的 props 选项。</p><p>父组件向子组件传递数据分为两种方式：动态和静态，这里先介绍静态方式。</p><p>子组件要显示的用 props 声明它期望获得的数据</p><p>修改上例中的代码，给 childNode 添加一个 props 选项和需要的forChildMsg数据;然后在父组件中的占位符添加特性的方式来传递数据。</p><pre><code>var childNode = { template: `    &lt;div&gt;     {{forChildMsg}}    &lt;/div&gt;    `, props: ["for-child-msg"]};var parentNode = { template: `    &lt;div&gt;     &lt;p&gt;parentNode&lt;/p&gt;     &lt;child for-child-msg="aaa"&gt;&lt;/child&gt;     &lt;child for-child-msg="bbb"&gt;&lt;/child&gt;    &lt;/div&gt;    `, components: {  child: childNode }};</code></pre><p><strong>命名规范</strong>对于 props 声明的属性，在父组件的 template 模板中，属性名需要使用中划线写法；</p><p>子组件 props 属性声明时，使用小驼峰或者中划线写法都可以；而子组件的模板使用从父组件传来的变量时，需要使用对应的小驼峰写法。别担心，Vue 能够正确识别出小驼峰和下划线命名法混用的变量，如这里的<code>forChildMsg</code>和<code>for-child-msg</code>是同一值。</p><p><strong>动态 props</strong></p><p>在模板中，要动态地绑定父组件的数据到子组件模板的 props，和绑定 Html 标签特性一样，使用v-bind绑定；</p><p>基于上述静态 props 的代码，这次只需要改动父组件：</p><pre><code>var parentNode = { template: `    &lt;div&gt;     &lt;p&gt;parentNode&lt;/p&gt;     &lt;child :for-child-msg="childMsg1"&gt;&lt;/child&gt;     &lt;child :for-child-msg="childMsg2"&gt;&lt;/child&gt;    &lt;/div&gt;    `, components: {  child: childNode }, data: function() {  return {   childMsg1: "Dynamic props msg for child-1",   childMsg2: "Dynamic props msg for child-2"  }; }};</code></pre><p>在父组件的 data 的 return 数据中的 childMsg1 和 childMsg2 会被传入子组件中，</p><p><strong>props 验证</strong>验证传入的 props 参数的数据规格，如果不符合数据规格，Vue 会发出警告。</p><p>能判断的所有种类（也就是 type 值）有：String, Number, Boolean, Function, Object, Array, Symbol</p><pre><code>Vue.component("example", { props: {  // 基础类型检测, null意味着任何类型都行  propA: Number,  // 多种类型  propB: [String, Number],  // 必传且是String  propC: {   type: String,   required: true  },  // 数字有默认值  propD: {   type: Number,   default: 101  },  // 数组、默认值是一个工厂函数返回对象  propE: {   type: Object,   default: function() {    console.log("propE default invoked.");    return { message: "I am from propE." };   }  },  // 自定义验证函数  propF: {   isValid: function(value) {    return value &gt; 100;   }  } }});let childNode = { template: "&lt;div&gt;{{forChildMsg}}&lt;/div&gt;", props: {  "for-child-msg": Number }};let parentNode = { template: `     &lt;div class="parent"&gt;      &lt;child :for-child-msg="msg"&gt;&lt;/child&gt;     &lt;/div&gt;    `, components: {  child: childNode }, data() {  return {   // 当这里是字符串 "123456"时会报错   msg: 123456  }; }};</code></pre><p>还可以在 props 定义的数据中加入自定义验证函数，当函数返回 false 时，输出警告。</p><p>比如我们把上述例子中的 childNode 的for-child-msg修改成一个对象，并包含一个名叫validator的函数，该命名是规定叫validator的，自定义函数名不会生效。</p><pre><code>let childNode = { template: "&lt;div&gt;{{forChildMsg}}&lt;/div&gt;", props: {  "for-child-msg": {   validator: function(value) {    return value &gt; 100;   }  } }};</code></pre><p>在这里我们给for-child-msg变量设置了validator函数，并且要求传入的值必须大于 100，否则报出警告。</p><p><strong>单向数据流</strong>props 是单向绑定的：当父组件的属性变化时，将传导给子组件，但是不会反过来。这是为了防止子组件五一修改父组件的状态。</p><p>所以不应该在子组件中修改 props 中的 ...

# %%
def segmentation(partition):
    import os
    import re

    import jieba
    import jieba.analyse
    import jieba.posseg as pseg
    import codecs

    abspath = "/root/words"

    # 结巴加载用户词典
    userDict_path = os.path.join(abspath, "ITKeywords.txt")
    jieba.load_userdict(userDict_path)

    # 停用词文本
    stopwords_path = os.path.join(abspath, "stopwords.txt")

    def get_stopwords_list():
        """返回stopwords列表"""
        stopwords_list = [i.strip()
                          for i in codecs.open(stopwords_path).readlines()]
        return stopwords_list

    # 所有的停用词列表
    stopwords_list = get_stopwords_list()

    # 分词
    def cut_sentence(sentence):
        """对切割之后的词语进行过滤，去除停用词，保留名词，英文和自定义词库中的词，长度大于2的词"""
        # print(sentence,"*"*100)
        # eg:[pair('今天', 't'), pair('有', 'd'), pair('雾', 'n'), pair('霾', 'g')]
        seg_list = pseg.lcut(sentence)
        seg_list = [i for i in seg_list if i.word not in stopwords_list]
        filtered_words_list = []
        for seg in seg_list:
            # print(seg)
            if len(seg.word) <= 1:
                continue
            elif seg.flag == "eng":
                if len(seg.word) <= 2:
                    continue
                else:
                    filtered_words_list.append(seg.word)
            elif seg.flag.startswith("n"):
                filtered_words_list.append(seg.word)
            elif seg.flag in ["x", "eng"]:  # 是自定一个词语或者是英文单词
                filtered_words_list.append(seg.word)
        return filtered_words_list

    for row in partition:
        sentence = re.sub("<.*?>", "", row.sentence)    # 替换掉标签数据
        words = cut_sentence(sentence)
        yield row.article_id, row.channel_id, words

# %%
words_df = article_dataframe.rdd.mapPartitions(segmentation).toDF(["article_id", "channel_id", "words"])

# %%
words_df.show()
# Out:
# +----------+----------+--------------------+
# |article_id|channel_id|               words|
# +----------+----------+--------------------+
# |         1|        17|[Vue, props, 用法, ...|
# |         2|        17|[vue, 响应式, 原理, mo...|
# |         3|        17|[JavaScript, 浅拷贝,...|
# |         4|        17|[vue2, vuex, elem...|
# |         5|        17|[immutability, Re...|
# |         6|        17|[node, npm, cnpm,...|
# |         7|        17|[Web, 工程师, 以太坊, 入...|
# |         8|        17|[Web, pa, api, we...|
# |         9|        17|[vue, 中用, 数据驱动, 视...|
# |        10|        17|[程序, WebSocket, 长...|
# |        11|        17|[flux, 架构, flux, ...|
# |        12|        17|[合格, TypeScript, ...|
# |        13|        17|[专属, 插件, Easy, Sl...|
# |        14|        17|[前后端分离, vue, 网站前台...|
# |        15|        17|[ajax, 页面, 重复提交, ...|
# |        17|        17|[JSsearch, 购物网站, ...|
# |        18|        17|[web, pa, react, ...|
# |        19|        17|[合格, 事顶, 项目, 自我介绍...|
# |        20|        17|[jQuery, 用法, jque...|
# |        21|        17|[Bootstrap, Modal...|
# +----------+----------+--------------------+

# %%
words_df.rdd.take(1)
# Out:
# [Row(article_id=1, channel_id=17, words=['Vue', 'props', '用法', '小结', 'Vue', 'props', '用法', '组件', '选项', 'props', 'Vue', '选项', '父子', '组件', '关系', 'props', 'events', '组件', 'props', '传递数据', '组件', '组件', 'events', '组件', '发送消息', '父子', '组件', '组件', 'pa', 'rent', 'child', '组件', '环境', '书写', '组件', '可维护性', '定义', '父子', '组件', 'Vue', '对象', 'var', 'childNode', 'template', 'div', 'childNode', 'div', 'var', 'pa', 'rentNode', 'template', 'div', 'child', 'child', 'child', 'child', 'div', 'components', 'child', 'childNode', '全栈', '交流', 'Ian', '人员', '技术', '瓶颈', '思维能力', 'Vue', 'components', 'pa', 'rent', 'pa', 'rentNode', 'div', 'pa', 'rent', 'pa', 'rent', 'div', 'childNode', '定义', 'template', 'div', '内容', 'childNode', '字符串', 'pa', 'rentNode', 'template', '定义', 'div', 'class', 'pa', 'rent', 'child', '组件', '静态', 'props', '组件', '实例', '作用域', '组件', '模板', '饮用', '组件', '数据', '组件', '组件', '数据', '组件', 'props', '选项', '组件', '向子', '组件', '传递数据', '方式', '动态', '静态', '静态', '方式', '组件', 'props', '声明', '数据', '上例', '代码', 'childNode', 'props', '选项', 'forChildMsg', '数据', '组件', '占位符', '特性', '方式', '传递数据', 'var', 'childNode', 'template', 'div', 'forChildMsg', 'div', 'props', 'child', 'msg', 'var', 'pa', 'rentNode', 'template', 'div', 'pa', 'rentNode', 'child', 'child', 'msg', 'aaa', 'child', 'child', 'child', 'msg', 'bbb', 'child', 'div', 'components', 'child', 'childNode', '命名规范', 'props', '声明', '属性', '组件', 'template', '模板', '属性', '中划线', '组件', 'props', '属性', '声明', '驼峰', '中划线', '组件', '模板', '组件', '驼峰', 'Vue', '驼峰', '命名', 'forChildMsg', 'child', 'msg', '动态', 'props', '模板', '动态', '组件', '数据', '组件', '模板', 'props', 'Html', '标签', '特性', 'bind', '静态', 'props', '代码', '组件', 'var', 'pa', 'rentNode', 'template', 'div', 'pa', 'rentNode', 'child', 'child', 'msg', 'childMsg1', 'child', 'child', 'child', 'msg', 'childMsg2', 'child', 'div', 'components', 'child', 'childNode', 'data', 'function', 'return', 'childMsg1', 'Dynamic', 'props', 'msg', 'child', 'childMsg2', 'Dynamic', 'props', 'msg', 'child', '组件', 'data', 'return', '数据', 'childMsg1', 'childMsg2', '组件', 'props', 'props', '参数', '数据', '规格', '数据', '规格', 'Vue', '警告', '种类', 'type', 'String', 'Number', 'Boolean', 'Function', 'Object', 'Array', 'SymbolVue', 'component', 'props', '基础', '类型', 'ul', '类型', '都行', 'propA', 'Number', '多种类型', 'propB', 'String', 'Number', 'String', 'propC', 'type', 'String', 'required', 'true', '数字', 'propD', 'type', 'Number', 'defa', 'ul', '数组', '工厂', '函数返回', '对象', 'propE', 'type', 'Object', 'defa', 'ul', 'function', 'console', 'log', 'propE', 'defa', 'ul', 'invoked', 'return', 'message', 'propE', '函数', 'propF', 'isValid', 'function', 'return', 'childNode', 'template', 'div', 'forChildMsg', 'div', 'props', 'child', 'msg', 'Number', 'pa', 'rentNode', 'template', 'div', 'class', 'pa', 'rent', 'child', 'child', 'msg', 'msg', 'child', 'div', 'components', 'child', 'childNode', 'data', 'return', '字符串', '时会', 'msg', 'props', '定义', '数据', '函数', '函数返回', 'false', '警告', '例子', 'childNode', 'child', 'msg', '一个对象', 'validator', '函数', '命名', 'validator', '自定义函数', '生效', 'childNode', 'template', 'div', 'forChildMsg', 'div', 'props', 'child', 'msg', 'validator', 'function', 'return', 'child', 'msg', 'validator', '函数', '警告', '单向', '数据流', 'props', '单向', '组件', '属性', '传导', '组件', '组件', '组件', '状态', '组件', 'props', 'Vue', '警告', 'childNode', 'template', 'div', 'class', 'child', 'div', 'pa', '组件', '数据', 'pa', 'input', 'model', 'forChildMsg', 'div', 'forChildMsg', 'div', 'props', 'child', 'msg', 'String', 'pa', 'rentNode', 'template', 'div', 'class', 'pa', 'rent', 'div', 'pa', '组件', '数据', 'pa', 'input', 'model', 'msg', 'div', 'msg', 'child', 'child', 'msg', 'msg', 'child', 'div', 'components', 'child', 'childNode', 'data', 'return', 'msg', 'defa', 'ul', 'string', '组件', '和子', '组件', '输入框', '组件', '数据', '和子', '组件', '数据', '组件', '输入框', '数据', '组件', '数据', 'props', '向子', '组件', '传递数据', '组件', '输入框', '浏览器', '错误', '警告', 'Vue', 'warn', 'Avoid', 'mutating', 'prop', 'directly', 'overwritten', 'pa', 'rent', 'component', 'renders', 'Instead', 'data', 'computed', 'p ...

# %%
# 词语与词频统计
from pyspark.ml.feature import CountVectorizer
# 总词汇的大小，文本中必须出现的次数
cv = CountVectorizer(inputCol="words", outputCol="countFeatures", vocabSize=200*10000, minDF=1.0)
# 训练词频统计模型
cv_model = cv.fit(words_df)

# %%
cv_result = cv_model.transform(words_df)

# %%
cv_result.show()
# Out:
# +----------+----------+--------------------+--------------------+
# |article_id|channel_id|               words|       countFeatures|
# +----------+----------+--------------------+--------------------+
# |         1|        17|[Vue, props, 用法, ...|(2509,[0,1,2,3,4,...|
# |         2|        17|[vue, 响应式, 原理, mo...|(2509,[0,1,3,4,5,...|
# |         3|        17|[JavaScript, 浅拷贝,...|(2509,[0,2,3,5,6,...|
# |         4|        17|[vue2, vuex, elem...|(2509,[0,3,4,7,8,...|
# |         5|        17|[immutability, Re...|(2509,[0,1,2,3,4,...|
# |         6|        17|[node, npm, cnpm,...|(2509,[0,3,6,7,10...|
# |         7|        17|[Web, 工程师, 以太坊, 入...|(2509,[0,1,2,3,4,...|
# |         8|        17|[Web, pa, api, we...|(2509,[0,3,7,8,16...|
# |         9|        17|[vue, 中用, 数据驱动, 视...|(2509,[0,4,5,9,15...|
# |        10|        17|[程序, WebSocket, 长...|(2509,[0,1,9,10,1...|
# |        11|        17|[flux, 架构, flux, ...|(2509,[0,1,2,4,5,...|
# |        12|        17|[合格, TypeScript, ...|(2509,[0,1,3,4,5,...|
# |        13|        17|[专属, 插件, Easy, Sl...|(2509,[0,2,3,5,6,...|
# |        14|        17|[前后端分离, vue, 网站前台...|(2509,[0,1,3,5,6,...|
# |        15|        17|[ajax, 页面, 重复提交, ...|(2509,[0,1,2,3,4,...|
# |        17|        17|[JSsearch, 购物网站, ...|(2509,[0,2,3,6,14...|
# |        18|        17|[web, pa, react, ...|(2509,[0,3,7,8,9,...|
# |        19|        17|[合格, 事顶, 项目, 自我介绍...|(2509,[0,3,4,5,6,...|
# |        20|        17|[jQuery, 用法, jque...|(2509,[0,1,2,3,4,...|
# |        21|        17|[Bootstrap, Modal...|(2509,[0,2,3,5,6,...|
# +----------+----------+--------------------+--------------------+

# %%
len(cv_model.vocabulary)
# Out:
# 2509

# %%
cv_result.rdd.take(1)
# Out:
# [Row(article_id=1, channel_id=17, words=['Vue', 'props', '用法', '小结', 'Vue', 'props', '用法', '组件', '选项', 'props', 'Vue', '选项', '父子', '组件', '关系', 'props', 'events', '组件', 'props', '传递数据', '组件', '组件', 'events', '组件', '发送消息', '父子', '组件', '组件', 'pa', 'rent', 'child', '组件', '环境', '书写', '组件', '可维护性', '定义', '父子', '组件', 'Vue', '对象', 'var', 'childNode', 'template', 'div', 'childNode', 'div', 'var', 'pa', 'rentNode', 'template', 'div', 'child', 'child', 'child', 'child', 'div', 'components', 'child', 'childNode', '全栈', '交流', 'Ian', '人员', '技术', '瓶颈', '思维能力', 'Vue', 'components', 'pa', 'rent', 'pa', 'rentNode', 'div', 'pa', 'rent', 'pa', 'rent', 'div', 'childNode', '定义', 'template', 'div', '内容', 'childNode', '字符串', 'pa', 'rentNode', 'template', '定义', 'div', 'class', 'pa', 'rent', 'child', '组件', '静态', 'props', '组件', '实例', '作用域', '组件', '模板', '饮用', '组件', '数据', '组件', '组件', '数据', '组件', 'props', '选项', '组件', '向子', '组件', '传递数据', '方式', '动态', '静态', '静态', '方式', '组件', 'props', '声明', '数据', '上例', '代码', 'childNode', 'props', '选项', 'forChildMsg', '数据', '组件', '占位符', '特性', '方式', '传递数据', 'var', 'childNode', 'template', 'div', 'forChildMsg', 'div', 'props', 'child', 'msg', 'var', 'pa', 'rentNode', 'template', 'div', 'pa', 'rentNode', 'child', 'child', 'msg', 'aaa', 'child', 'child', 'child', 'msg', 'bbb', 'child', 'div', 'components', 'child', 'childNode', '命名规范', 'props', '声明', '属性', '组件', 'template', '模板', '属性', '中划线', '组件', 'props', '属性', '声明', '驼峰', '中划线', '组件', '模板', '组件', '驼峰', 'Vue', '驼峰', '命名', 'forChildMsg', 'child', 'msg', '动态', 'props', '模板', '动态', '组件', '数据', '组件', '模板', 'props', 'Html', '标签', '特性', 'bind', '静态', 'props', '代码', '组件', 'var', 'pa', 'rentNode', 'template', 'div', 'pa', 'rentNode', 'child', 'child', 'msg', 'childMsg1', 'child', 'child', 'child', 'msg', 'childMsg2', 'child', 'div', 'components', 'child', 'childNode', 'data', 'function', 'return', 'childMsg1', 'Dynamic', 'props', 'msg', 'child', 'childMsg2', 'Dynamic', 'props', 'msg', 'child', '组件', 'data', 'return', '数据', 'childMsg1', 'childMsg2', '组件', 'props', 'props', '参数', '数据', '规格', '数据', '规格', 'Vue', '警告', '种类', 'type', 'String', 'Number', 'Boolean', 'Function', 'Object', 'Array', 'SymbolVue', 'component', 'props', '基础', '类型', 'ul', '类型', '都行', 'propA', 'Number', '多种类型', 'propB', 'String', 'Number', 'String', 'propC', 'type', 'String', 'required', 'true', '数字', 'propD', 'type', 'Number', 'defa', 'ul', '数组', '工厂', '函数返回', '对象', 'propE', 'type', 'Object', 'defa', 'ul', 'function', 'console', 'log', 'propE', 'defa', 'ul', 'invoked', 'return', 'message', 'propE', '函数', 'propF', 'isValid', 'function', 'return', 'childNode', 'template', 'div', 'forChildMsg', 'div', 'props', 'child', 'msg', 'Number', 'pa', 'rentNode', 'template', 'div', 'class', 'pa', 'rent', 'child', 'child', 'msg', 'msg', 'child', 'div', 'components', 'child', 'childNode', 'data', 'return', '字符串', '时会', 'msg', 'props', '定义', '数据', '函数', '函数返回', 'false', '警告', '例子', 'childNode', 'child', 'msg', '一个对象', 'validator', '函数', '命名', 'validator', '自定义函数', '生效', 'childNode', 'template', 'div', 'forChildMsg', 'div', 'props', 'child', 'msg', 'validator', 'function', 'return', 'child', 'msg', 'validator', '函数', '警告', '单向', '数据流', 'props', '单向', '组件', '属性', '传导', '组件', '组件', '组件', '状态', '组件', 'props', 'Vue', '警告', 'childNode', 'template', 'div', 'class', 'child', 'div', 'pa', '组件', '数据', 'pa', 'input', 'model', 'forChildMsg', 'div', 'forChildMsg', 'div', 'props', 'child', 'msg', 'String', 'pa', 'rentNode', 'template', 'div', 'class', 'pa', 'rent', 'div', 'pa', '组件', '数据', 'pa', 'input', 'model', 'msg', 'div', 'msg', 'child', 'child', 'msg', 'msg', 'child', 'div', 'components', 'child', 'childNode', 'data', 'return', 'msg', 'defa', 'ul', 'string', '组件', '和子', '组件', '输入框', '组件', '数据', '和子', '组件', '数据', '组件', '输入框', '数据', '组件', '数据', 'props', '向子', '组件', '传递数据', '组件', '输入框', '浏览器', '错误', '警告', 'Vue', 'warn', 'Avoid', 'mutating', 'prop', 'directly', 'overwritten', 'pa', 'rent', 'component', 'renders', 'Instead', 'data', 'computed', 'p ...

# %%
cv_model.vocabulary
# Out:
# ['pa',
#  'data',
#  'var',
#  'ul',
#  '数据',
#  'return',
#  'function',
#  'node',
#  'web',
#  '组件',
#  'config',
#  'obj',
#  'console',
#  'log',
#  'div',
#  'const',
#  'npm',
#  '文件',
#  '节点',
#  'index',
#  'keys',
#  'vue',
#  '.a',
#  'bar',
#  'key',
#  'child',
#  '代码',
#  '属性',
#  'amp',
#  '项目',
#  'type',
#  'class',
#  '事件',
#  '方法',
#  '函数',
#  '对象',
#  'url',
#  '元素',
#  '文本',
#  '内容',
#  'fragment',
#  'test',
#  '浏览器',
#  '&#',
#  '服务器',
#  'WebSocket',
#  'msg',
#  'left',
#  'string',
#  'props',
#  'true',
#  '用户',
#  'loader',
#  'position',
#  'style',
#  '模块',
#  '资源',
#  '页面',
#  'state',
#  'func',
#  '版本',
#  '合约',
#  'export',
#  '信息',
#  'css',
#  'slider',
#  '定义',
#  '时间',
#  '数组',
#  'DOM',
#  'item',
#  'model',
#  '程序',
#  'width',
#  'val',
#  'http',
#  'html',
#  'document',
#  'Vue',
#  '参数',
#  'public',
#  '状态',
#  'defa',
#  'script',
#  'json',
#  '.h',
#  'web3',
#  '类型',
#  'template',
#  'window',
#  'obj2',
#  'Array',
#  'JSON',
#  'forChildMsg',
#  '以太坊',
#  '方式',
#  '交易',
#  'error',
#  'Object',
#  'update',
#  'import',
#  '文章',
#  '语法',
#  '情况',
#  'layer',
#  'top',
#  'mod',
#  'mongodb',
#  '用法',
#  'Function',
#  'input',
#  'click',
#  'store',
#  'number',
#  'label',
#  'ajax',
#  'react',
#  'list',
#  'set',
#  'border',
#  'Promise',
#  '源码',
#  'vuex',
#  'Control',
#  '方案',
#  'options',
#  'install',
#  'childNode',
#  'src',
#  'ownChildMsg',
#  '功能',
#  'text',
#  'ckage',
#  'rent',
#  'res',
#  'box',
#  'interface',
#  'Store',
#  '字符串',
#  'init',
#  'immutable',
#  'add',
#  'min',
#  'array',
#  'server',
#  'require',
#  'center',
#  'className',
#  'margin',
#  'https',
#  'matchs',
#  '官方',
#  'forEach',
#  'match',
#  'body',
#  'babel',
#  'dev',
#  '域名',
#  'app',
#  'prototype',
#  'Actions',
#  '全局',
#  '技术',
#  'tch',
#  'async',
#  '命令',
#  'height',
#  'Number',
#  'Watcher',
#  'children',
#  'dis',
#  'arr',
#  'object',
#  'State',
#  'float',
#  'count',
#  'Modified',
#  '区块链',
#  'attr',
#  'IFC',
#  'max',
#  '地址',
#  'foo',
#  'resolve',
#  '过程',
#  'length',
#  '元素节点',
#  'callback',
#  '目录',
#  'jQuery',
#  '事件委托',
#  'title',
#  'token',
#  'cli',
#  'Cache',
#  'Web',
#  'JavaScript',
#  'call',
#  '插件',
#  'target',
#  '部署',
#  'newVal',
#  'textReg',
#  'NewState',
#  'rawTextContent',
#  '客户端',
#  'TypeScript',
#  'Action',
#  'axios',
#  '性能',
#  'positions',
#  'dist',
#  'plugin',
#  'gas',
#  'textContent',
#  'rse',
#  'TOKEN',
#  'truffle',
#  'display',
#  'tml',
#  'save',
#  '基础',
#  '智能',
#  '协议',
#  'actionTypes',
#  'registry',
#  'run',
#  'await',
#  'false',
#  'city',
#  'message',
#  'exports',
#  '原因',
#  'dding',
#  'MVVM',
#  'form',
#  '规范',
#  'trackHeight',
#  '文件夹',
#  '数据库',
#  '东西',
#  'r2',
#  'event',
#  '路由',
#  'color',
#  '回调函数',
#  '列表',
#  '镜像',
#  'constructor',
#  'align',
#  'dragsort',
#  'JSsearch',
#  '菜单',
#  '视图',
#  'icon',
#  'String',
#  '平台',
#  '服务端',
#  'wrap',
#  '建议',
#  '记录',
#  'push',
#  'initDom',
#  'DataBase',
#  'compile',
#  'home',
#  'ES6',
#  'mongod',
#  'track',
#  'api',
#  '效果',
#  'eth',
#  'flux',
#  'stateType',
#  'undefined',
#  'indexOf',
#  'xxx',
#  'childNodes',
#  'dom',
#  '拷贝',
#  'modal',
#  'col',
#  '原始数据',
#  'Mutation',
#  '例子',
#  'data2',
#  'age',
#  'commit',
#  '__',
#  'CompileUtils',
#  'express',
#  'header',
#  'ppendChild',
#  'balance',
#  'cnpm',
#  '首席',
#  'Getter',
#  'suc',
#  'rentNode',
#  'str',
#  'typeof',
#  'Local',
#  '苏南',
#  'scale',
#  'router',
#  'tcher',
#  '脚本',
#  '框架',
#  '关系',
#  'pos',
#  'start',
#  'Component',
#  '系统',
#  'element',
#  '网站',
#  '房间',
#  'apply',
#  '消息',
#  'components',
#  'search',
#  '指令',
#  'Add',
#  'block',
#  'newTextContent',
#  'prop',
#  '同学',
#  'wrapper',
#  'cache',
#  'SocketIO',
#  'ckPlugin',
#  '以太',
#  'roles',
#  'remove',
#  'getElementById',
#  '模板',
#  'property',
#  'API',
#  'HTTP',
#  'bind',
#  'cursor',
#  '选项',
#  '架构',
#  'firstChild',
#  'nodejs',
#  '特性',
#  'defineProperty',
#  '层级',
#  'Dep',
#  '本地缓存',
#  'stringify',
#  '安装包',
#  '重绘',
#  '游戏',
#  'ssign',
#  '入口',
#  'button',
#  '输入框',
#  'main',
#  'absolute',
#  'org',
#  'evt',
#  '环境',
#  '细节',
#  'request',
#  'unsubscribe',
#  'inline',
#  'preset',
#  'catch',
#  'isElementNode',
#  'View',
#  'content',
#  'getters',
#  'Node',
#  'pointer',
#  'circle',
#  '响应头',
#  'Event',
#  '腾讯',
#  'backgroundColor',
#  '工具',
#  'socket',
#  '效率',
#  '单向',
#  '交流',
#  'actionType',
#  '开发者',
#  'toString',
#  'component',
#  'modalDialog',
#  'Prop',
#  'reject',
#  '模式',
#  'proxy',
#  '权限',
#  '核心',
#  '作用域',
#  '服务器返回',
#  'env',
#  'comp',
#  'ckRemindType',
#  '事情',
#  '剪刀',
#  'www',
#  '父子',
#  'dataType',
#  'HTTPS',
#  '高度',
#  '石头',
#  'output',
#  '结构',
#  'counter',
#  '动态',
#  '业务',
#  'splice',
#  'response',
#  'nginx',
#  'Watch',
#  'arg',
#  '错误',
#  'Modal',
#  'ETag',
#  'watcher',
#  'AjaxResponse',
#  '根目录',
#  'reg',
#  'HtmlWeb',
#  'nodeType',
#  'names',
#  '数据驱动',
#  'None',
#  'accounts',
#  '原生',
#  '新建',
#  'selector',
#  '兴趣',
#  '按钮',
#  '静态',
#  '区别',
#  '次数',
#  'scripts',
#  '代表',
#  '开发环境',
#  '原理',
#  'innerHTML',
#  'Expires',
#  '即时通讯',
#  'render',
#  'ram',
#  'getModelValue',
#  'success',
#  'getInterval',
#  'solid',
#  'bin',
#  '滑块',
#  'node2Fragment',
#  'address',
#  'onBarMoveBegin',
#  'build',
#  '形式',
#  'oldVal',
#  'sync',
#  '修改时间',
#  'newState',
#  'ddr',
#  'defineReactive',
#  '网络',
#  'vue2',
#  'background',
#  'diamond',
#  'optimization',
#  'size',
#  'flex',
#  'decorator',
#  'rawObj',
#  'trim',
#  '重复提交',
#  '子节点',
#  'line',
#  'production',
#  'nodeName',
#  'mode',
#  'send',
#  'Last',
#  'split',
#  'javascript',
#  '思想',
#  '指向',
#  'lang',
#  '命令行',
#  '配置文件',
#  '点击事件',
#  'Mod',
#  'Dis',
#  'extends',
#  'Socket',
#  'cookie',
#  'Set',
#  '逻辑',
#  'barStack',
#  'lastValue',
#  '私钥',
#  'tougu',
#  'updateTextNode',
#  '人员',
#  'Observer',
#  'Since',
#  'BFC',
#  '小伙伴',
#  'DECREMENT',
#  'getTodayWeather',
#  'barOffset',
#  '能力',
#  'Name',
#  'Javascript',
#  'entry',
#  '附件',
#  'windows',
#  'development',
#  '格式',
#  'Access',
#  'onBarMoveEnd',
#  'iframe',
#  '后台',
#  'i++',
#  '跨域',
#  'subs',
#  'deepclone',
#  '数据流',
#  'map',
#  'compileModelAttr',
#  '深拷贝',
#  'unset',
#  '成本',
#  'sender',
#  'newValue',
#  'uint',
#  '笔者',
#  '入门',
#  '属性值',
#  'GMT',
#  'original',
#  'dirname',
#  'onBarMoving',
#  '博客',
#  'prevState',
#  'session',
#  'lstLayerLoad',
#  '警告',
#  'Ajax',
#  'args',
#  'updateCb',
#  '利用',
#  'EventFunc',
#  'radius',
#  'net',
#  'nodeJs',
#  'plugins',
#  'BUG',
#  'Error',
#  'evtMap',
#  '帐户',
#  'tokenOrCallback',
#  'process',
#  '优点',
#  'php',
#  'contentType',
#  'ajaxSubmit',
#  'oldValue',
#  'lstAjaxUrl',
#  'taobao',
#  '淘宝',
#  'Math',
#  'barNumber',
#  'React',
#  'pending',
#  'bootstrap',
#  '运行时',
#  '字段',
#  'subscribe',
#  'jquery',
#  '提交表单',
#  '钩子',
#  '代理',
#  'recommend',
#  'rams',
#  'filename',
#  'INCREMENT',
#  'action',
#  '体验',
#  'calc',
#  'service',
#  '格式化',
#  '声明',
#  '文档',
#  'throw',
#  'draggable',
#  '证书',
#  'getJSON',
#  '链接',
#  'closest',
#  'unshift',
#  'Virtual',
#  'square',
#  'merge',
#  'transform',
#  'middle',
#  'ShenZhen',
#  'List',
#  'deep',
#  'hobby',
#  'isDirective',
#  'Allow',
#  'SET',
#  '配置项',
#  '样式',
#  'Match',
#  '宿舍',
#  'show',
#  'ctionTypes',
#  '后台管理',
#  'charset',
#  'copy',
#  'attrs',
#  'txHash',
#  '协商',
#  'jpg',
#  'objClone',
#  'Create',
#  '请求头',
#  '空间',
#  '常规',
#  'vnode',
#  'toFixed',
#  'otf',
#  'admin',
#  '平头',
#  'tslint',
#  'compileTextNode',
#  'svg',
#  'actions',
#  '标签',
#  'loadStyle',
#  'head',
#  'png',
#  '篇文章',
#  '教程',
#  'python',
#  '玩家',
#  '余额',
#  'HTML',
#  '机制',
#  '命名',
#  'Jan',
#  'goLink',
#  '源代码',
#  '场景',
#  '顺序',
#  '栈内存',
#  '静态资源',
#  'computed',
#  '跨站',
#  '矿工',
#  'isTextNode',
#  'touzi',
#  'mouseOffset',
#  'void',
#  'Immutability',
#  '网络请求',
#  '哈希',
#  '速度',
#  '服务器端',
#  'gif',
#  'eot',
#  'events',
#  '异步编程',
#  'woff',
#  '步骤',
#  '布局',
#  'cmd',
#  'vertical',
#  'Helpers',
#  'setModelValue',
#  '绑定事件',
#  'isArray',
#  'method',
#  '宽度',
#  '引用数据类型',
#  'accessedRouters',
#  'woff2',
#  '全栈',
#  'Map',
#  'row',
#  '外层',
#  '程序员',
#  'validator',
#  'AxiosResponse',
#  'itemList',
#  '容器',
#  'ttf',
#  'context',
#  '路径',
#  'items',
#  'listen',
#  'connection',
#  '瓶颈',
#  '商品',
#  'bars',
#  'testrpc',
#  'inArray',
#  '公司',
#  'searchvalue',
#  '委托',
#  '模块化',
#  'localhost',
#  '编辑器',
#  'gasPrice',
#  'github',
#  '思维能力',
#  'uint256',
#  '流程',
#  'timeout',
#  '团队',
#  '浅拷贝',
#  'copyObj',
#  'dialogOffset',
#  'node4',
#  '传递数据',
#  '前后端分离',
#  '整体',
#  'baidu',
#  '发布者',
#  'login',
#  'Global',
#  'EFF',
#  'Model',
#  '资金',
#  '单位',
#  'Web应用程序',
#  '块级元素',
#  '选型',
#  'hidden',
#  'event1',
#  'array2',
#  'EasySliderBar',
#  'methods',
#  'types',
#  '上海',
#  'email',
#  'CLI',
#  'dragSelector',
#  'NPM',
#  '自适应',
#  '命令行工具',
#  'Flux',
#  'ele',
#  '大型项目',
#  'floor',
#  'Get',
#  'jsx',
#  'moneyIncomePay',
#  'CSS选择器',
#  'source',
#  '方向',
#  'exampleProxy',
#  'txt',
#  'XSRF',
#  '团队协作',
#  'outdb',
#  '技术栈',
#  'txn',
#  '一个对象',
#  'trinoc',
#  'uninstall',
#  'relative',
#  '传送门',
#  'onChildChanged',
#  '嵌套',
#  'devweb',
#  '长连接',
#  'cjg',
#  '分数',
#  'cancelToken',
#  'relatedTarget',
#  'newItemList',
#  'list3',
#  'addr',
#  'color1',
#  '数量',
#  '快捷键',
#  'applet',
#  '热更新',
#  '解决方案',
#  'root',
#  'exclude',
#  'movingPosition',
#  'auto',
#  'clientX',
#  'java',
#  'GFC',
#  '修饰符',
#  'propE',
#  '垂直居中',
#  'customClone',
#  '启动服务',
#  '缺点',
#  '目标',
#  '语法糖',
#  'babelrc',
#  'nonce',
#  'Integer',
#  'clientWidth',
#  'publish',
#  '局部',
#  'objB',
#  'ttp',
#  'filter',
#  'UTF',
#  'cancel',
#  'table',
#  '提交数据',
#  'createElement',
#  '层面',
#  '传统',
#  '标记',
#  'SSE',
#  'propA',
#  'boolean',
#  'Router',
#  'childMsg2',
#  '水平居中',
#  'Type',
#  'vdom',
#  'mutations',
#  'barWidth',
#  'aaa',
#  'tsconfig',
#  '父子关系',
#  '数据类型',
#  '表单',
#  '浏览器缓存',
#  '地方',
#  'code',
#  '使用细节',
#  '原创',
#  '连胜',
#  '主目录',
#  'warn',
#  'font',
#  '源地址',
#  'ajaxForm',
#  '返回值',
#  '名称',
#  '开发效率',
#  'watch',
#  '内存空间',
#  'solidity',
#  'getValidLeft',
#  'contract',
#  '基础数据类型',
#  'getCityWeather',
#  'status',
#  'removePending',
#  'utils',
#  'blog',
#  '工程师',
#  '感觉',
#  '语句',
#  'Content',
#  '痛点',
#  'user',
#  '下载地址',
#  '感兴趣',
#  'assert',
#  '赋值',
#  '新手入门',
#  'mRes',
#  '作者',
#  '生命周期',
#  '技术原理',
#  '选择器',
#  '5e',
#  'childs',
#  'Bootstrap',
#  'getIn',
#  'instance',
#  'info',
#  'Server',
#  'toggle',
#  'userInfo',
#  'immutability',
#  'GenerateRoutes',
#  '清空',
#  'robomongod',
#  'formtosub',
#  'obj3',
#  'getter',
#  'LoginByEmail',
#  'Wed',
#  'notEqual',
#  '行内元素',
#  'emit',
#  'Componentexport',
#  '语言',
#  'sizing',
#  'post',
#  '概念',
#  'views',
#  'isNaN',
#  '数字',
#  '内存',
#  '脚手架',
#  '规则',
#  '风险',
#  '安全性',
#  'objA',
#  '驼峰',
#  'JSX',
#  'port',
#  '名字',
#  '源目录',
#  '思路',
#  '前言',
#  '处理程序',
#  'XSS',
#  '拦截器',
#  'sleep',
#  'movingLeft',
#  '书写',
#  '个字符',
#  '开源',
#  '生效',
#  'demo',
#  'EOS',
#  '示例',
#  'onPersonChanged',
#  'join',
#  'GetInfo',
#  'lstAjaxRes',
#  'CSRF',
#  'dep',
#  'trans',
#  'barHeight',
#  '状态码',
#  'ReducerFunc',
#  '面向',
#  'Agent',
#  'submit',
#  'getToken',
#  'NULL',
#  'childMsg1',
#  'proportion',
#  'labelWidth',
#  'ddClass',
#  '礼貌',
#  '课程',
#  'FFC',
#  '状态机',
#  '事件触发',
#  '使用者',
#  '枚举',
#  '动态绑定',
#  'mongoimport',
#  'geX',
#  'data1',
#  'sendObj',
#  '表格',
#  'extract',
#  'addUserBalance',
#  '我会',
#  '反向代理',
#  'clicli',
#  '案例',
#  'URL',
#  'Return',
#  '职位',
#  '同事',
#  'delete',
#  'GetTodayWeatherParam',
#  '校验',
#  'deploy',
#  'meta',
#  'stateFoo',
#  '代币',
#  '队列',
#  'privateKey',
#  '光标',
#  'Cookie',
#  'ddEventListener',
#  'middleware',
#  'enum',
#  'strFormCode',
#  'VDOM',
#  '附属品',
#  '数据格式',
#  'PHP',
#  'Php',
#  'es6',
#  'mine',
#  'alert',
#  '块级作用域',
#  ...]

# %%
from pyspark.ml.feature import IDF
idf = IDF(inputCol="countFeatures", outputCol="idfFeatures")
idfModel = idf.fit(cv_result)

# %%
idfModel.idf
# Out:
# DenseVector([0.0, 0.6466, 0.6466, 0.1542, 0.5596, 0.4055, 0.3365, 0.8473, 0.9651, 0.7419, 1.0986, 1.2528, 0.4796, 0.4055, 0.9651, 0.7419, 1.0986, 0.5596, 1.2528, 0.8473, 1.6582, 0.8473, 0.5596, 1.9459, 1.0986, 1.6582, 0.2719, 1.2528, 0.6466, 0.6466, 0.9651, 0.8473, 0.6466, 0.3365, 0.6466, 0.5596, 1.0986, 1.4351, 1.6582, 0.4796, 2.3514, 1.2528, 0.8473, 1.9459, 0.9651, 2.3514, 1.6582, 1.4351, 1.0986, 1.9459, 0.6466, 0.7419, 1.6582, 1.6582, 1.2528, 1.2528, 1.9459, 0.6466, 1.6582, 1.9459, 0.8473, 2.3514, 1.4351, 0.8473, 1.0986, 2.3514, 1.0986, 0.9651, 0.7419, 1.4351, 1.4351, 1.6582, 1.6582, 1.2528, 1.4351, 0.9651, 1.2528, 1.0986, 1.4351, 0.4796, 1.4351, 1.0986, 1.6582, 1.0986, 0.9651, 0.6466, 2.3514, 0.7419, 1.6582, 1.2528, 2.3514, 1.0986, 1.4351, 2.3514, 2.3514, 0.6466, 2.3514, 1.4351, 0.8473, 1.6582, 1.9459, 0.8473, 1.6582, 0.8473, 1.9459, 1.4351, 1.4351, 1.9459, 1.0986, 1.2528, 1.2528, 1.6582, 1.6582, 1.6582, 2.3514, 1.6582, 1.6582, 1.0986, 1.2528, 1.4351, 1.2528, 1.2528, 1.4351, 2.3514, 1.9459, 1.9459, 1.4351, 2.3514, 1.2528, 2.3514, 0.7419, 0.9651, 1.4351, 1.6582, 1.2528, 1.4351, 1.9459, 2.3514, 1.0986, 1.2528, 2.3514, 1.2528, 1.9459, 1.9459, 1.2528, 1.4351, 1.6582, 2.3514, 1.9459, 1.0986, 2.3514, 1.4351, 1.6582, 2.3514, 1.2528, 1.9459, 1.4351, 2.3514, 1.4351, 1.0986, 2.3514, 1.2528, 1.0986, 1.4351, 1.4351, 1.0986, 1.2528, 1.4351, 2.3514, 2.3514, 1.6582, 1.9459, 1.0986, 2.3514, 2.3514, 2.3514, 2.3514, 2.3514, 2.3514, 2.3514, 1.9459, 1.0986, 2.3514, 1.4351, 0.8473, 1.2528, 2.3514, 1.4351, 1.0986, 1.6582, 2.3514, 1.6582, 1.6582, 1.4351, 2.3514, 1.4351, 1.2528, 1.0986, 0.9651, 1.4351, 1.6582, 2.3514, 2.3514, 2.3514, 2.3514, 1.6582, 2.3514, 1.9459, 2.3514, 1.0986, 2.3514, 2.3514, 1.9459, 2.3514, 2.3514, 1.4351, 1.6582, 2.3514, 1.6582, 1.2528, 1.9459, 1.0986, 2.3514, 1.9459, 2.3514, 2.3514, 1.4351, 1.9459, 1.0986, 1.9459, 1.0986, 1.4351, 0.9651, 1.4351, 1.9459, 1.9459, 1.4351, 2.3514, 1.6582, 1.4351, 1.0986, 1.9459, 1.6582, 1.9459, 1.9459, 1.6582, 1.6582, 1.9459, 1.9459, 1.6582, 2.3514, 2.3514, 1.9459, 1.6582, 1.9459, 1.6582, 1.4351, 1.4351, 1.9459, 1.2528, 1.4351, 1.0986, 2.3514, 2.3514, 2.3514, 2.3514, 1.2528, 2.3514, 2.3514, 1.2528, 1.0986, 2.3514, 2.3514, 2.3514, 1.2528, 1.6582, 2.3514, 1.9459, 1.9459, 1.6582, 2.3514, 2.3514, 2.3514, 2.3514, 1.2528, 2.3514, 1.6582, 1.9459, 1.9459, 2.3514, 1.4351, 1.9459, 1.9459, 2.3514, 2.3514, 2.3514, 2.3514, 2.3514, 2.3514, 1.9459, 1.0986, 2.3514, 2.3514, 2.3514, 1.6582, 2.3514, 1.6582, 1.4351, 1.2528, 2.3514, 1.4351, 1.6582, 1.4351, 1.6582, 1.2528, 2.3514, 1.9459, 1.6582, 1.9459, 2.3514, 1.9459, 1.9459, 1.6582, 2.3514, 2.3514, 1.6582, 2.3514, 1.9459, 2.3514, 1.9459, 2.3514, 2.3514, 2.3514, 1.6582, 1.9459, 1.9459, 1.6582, 1.6582, 1.4351, 1.6582, 1.6582, 1.9459, 2.3514, 1.9459, 1.0986, 1.6582, 1.6582, 2.3514, 2.3514, 1.6582, 2.3514, 1.6582, 2.3514, 1.6582, 1.6582, 1.9459, 1.9459, 1.6582, 1.6582, 2.3514, 2.3514, 1.2528, 1.6582, 1.6582, 2.3514, 2.3514, 1.9459, 1.9459, 2.3514, 2.3514, 1.6582, 1.9459, 1.6582, 1.9459, 2.3514, 2.3514, 1.9459, 2.3514, 2.3514, 0.9651, 2.3514, 1.6582, 1.6582, 1.2528, 2.3514, 1.4351, 1.4351, 1.9459, 2.3514, 1.9459, 1.6582, 1.4351, 2.3514, 2.3514, 1.4351, 1.9459, 1.9459, 1.6582, 2.3514, 2.3514, 1.6582, 2.3514, 1.0986, 1.9459, 1.9459, 2.3514, 1.9459, 2.3514, 1.9459, 1.9459, 2.3514, 1.2528, 1.9459, 1.9459, 1.9459, 1.9459, 2.3514, 1.9459, 0.9651, 2.3514, 2.3514, 1.9459, 2.3514, 1.9459, 2.3514, 2.3514, 2.3514, 1.9459, 1.6582, 2.3514, 2.3514, 1.4351, 1.9459, 1.9459, 1.2528, 1.4351, 1.9459, 1.6582, 1.9459, 1.6582, 1.2528, 1.9459, 1.4351, 1.9459, 2.3514, 2.3514, 1.9459, 1.9459, 2.3514, 1.6582, 2.3514, 1.6582, 2.3514, 2.3514, 2.3514, 1.9459, 2.3514, 2.3514, 1.4351, 1.9459, 1.9459, 2.3514, 2.3514, 2.3514, 2.3514, 1.6582, 2.3514, 1.6582, 2.3514, 2.3514, 1.2528, 2.3514, 2.3514, 2.3514, 1.9459, 2.3514, 2.3514, 1.9459, 1.9459, 2.3514, 1.9459, 1.9459, 2.3514, 1.9459, 1.4351, 1.4351, 1.6582, 1.9459, 1.9459, 1.6582, 1.9459, 1.6582, 2.3514, 1.9459, 2.3514, 2.3514, 1.9459, 1.6582, 2.3514 ...

# %% [markdown]
# ### 计算N篇文章数据的TFIDF值

# %%
from pyspark.ml.feature import CountVectorizerModel
from pyspark.ml.feature import IDFModel

# %%
cv_model = CountVectorizerModel.load('/headlines/countVectorizerOfArticleWords.model')

# %%
idf_model = IDFModel.load('/headlines/IDFOfArticleWords.model')

# %%
keywords_list_with_idf = list(zip(cv_model.vocabulary, idf_model.idf.toArray()))

# %%
keywords_list_with_idf
# Out:
# [('&#', 1.417829594344155),
#  ('pa', 0.6651385256756351),
#  ('ul', 0.8070591229443697),
#  ('代码', 0.7368239176481552),
#  ('方法', 0.7506253985501485),
#  ('数据', 0.9375297590538404),
#  ('return', 1.1584986818528347),
#  ('对象', 1.2765716628665975),
#  ('name', 1.3833429138490618),
#  ('this', 1.6247297855214076),
#  ('public', 1.7540399682870398),
#  ('int', 1.6612207991983439),
#  ('new', 1.3335127364488795),
#  ('问题', 0.8151384673357938),
#  ('函数', 1.4147095597213706),
#  ('.a', 1.2475641921221166),
#  ('class', 1.3562548221032567),
#  ('文件', 1.2163286406564702),
#  ('amp', 1.5313880611157102),
#  ('com', 0.9229090811983397),
#  ('元素', 1.7964130603067618),
#  ('function', 1.7912981813618367),
#  ('用户', 1.2794959063944176),
#  ('String', 1.9240331178651056),
#  ('内容', 0.7449604375370865),
#  ('时候', 0.9169217434065458),
#  ('var', 1.8734436358233233),
#  ('参数', 1.2650616316269794),
#  ('for', 1.254061482600779),
#  ('属性', 1.5263663508338299),
#  ('方式', 0.9338361580079647),
#  ('void', 1.841161167761987),
#  ('data', 1.8557185317252085),
#  ('__', 2.546746774645867),
#  ('the', 1.9411633046990937),
#  ('技术', 1.5675408705788416),
#  ('value', 1.873866161122443),
#  ('结果', 1.158246124710439),
#  ('信息', 1.1976725523180902),
#  ('log', 2.0027395343490673),
#  ('定义', 1.281986955479544),
#  ('类型', 1.4151250023220814),
#  ('项目', 1.430106667940106),
#  ('时间', 1.2046218506112962),
#  ('import', 1.9502451027406746),
#  ('div', 2.5311321579844517),
#  ('线程', 2.574744124033075),
#  ('系统', 1.3915710367771266),
#  ('情况', 1.0592279935689197),
#  ('print', 2.3394468287742134),
#  ('节点', 2.3044612661522734),
#  ('.h', 1.4393383874831644),
#  ('http', 1.4940207167716042),
#  ('self', 2.914287511336415),
#  ('功能', 1.2030120279447727),
#  ('key', 2.1520765775202793),
#  ('true', 1.6357340737374313),
#  ('res', 2.169783907068485),
#  ('type', 1.8571490481086088),
#  ('java', 1.7717745060389738),
#  ('数组', 2.0402929239809673),
#  ('数据库', 1.8724584371792108),
#  ('组件', 2.280270854003292),
#  ('过程', 1.269644626270957),
#  ('console', 2.4320156129338333),
#  ('https', 1.2886340962790102),
#  ('index', 2.056845334549614),
#  ('页面', 1.816074026262823),
#  ('状态', 1.7526247166355668),
#  ('程序', 1.6171091036206826),
#  ('get', 1.8455335558537238),
#  ('test', 2.22380203051133),
#  ('服务器', 1.96659702559428),
#  ('static', 2.0184056510934667),
#  ('from', 1.8911063342652372),
#  ('命令', 2.020360898294693),
#  ('private', 2.232367393370253),
#  ('else', 1.7483495207497055),
#  ('字符串', 1.9605360896845399),
#  ('org', 2.2521176026854404),
#  ('模块', 2.0921964649825573),
#  ('out', 2.2857142946828337),
#  ('模型', 2.2947576859695347),
#  ('总结', 1.6396645174491273),
#  ('System', 2.4040202571458136),
#  ('算法', 2.035203572950485),
#  ('目录', 1.899164704810216),
#  ('false', 1.8536916285068603),
#  ('消耗', 3.1328231414841228),
#  ('list', 2.2459675218001025),
#  ('部分', 1.4123685057710609),
#  ('Java', 2.0721865445164034),
#  ('实例', 1.937703700857387),
#  ('www', 1.499075867197057),
#  ('const', 2.5684230501062495),
#  ('root', 2.585879142723225),
#  ('任务', 2.259547977428733),
#  ('size', 2.236340328800421),
#  ('大家', 1.475627199007823),
#  ('text', 2.1484859093895508),
#  ('url', 2.28791420331586),
#  ('版本', 1.6448794588661733),
#  ('浏览器', 2.0286039779691163),
#  ('内存', 2.08817395686245),
#  ('main', 1.876310920215046),
#  ('Python', 2.3889740436146356),
#  ('事件', 2.2787914074690474),
#  ('文章', 1.5470125914600148),
#  ('user', 2.414043996900961),
#  ('and', 1.9691246893681704),
#  ('string', 2.406416807262336),
#  ('模式', 1.863031009350594),
#  ('列表', 1.9649497483763214),
#  ('图片', 2.1460170771270457),
#  ('地址', 1.7123502701871516),
#  ('公司', 2.073389672794679),
#  ('索引', 2.624713290732596),
#  ('let', 2.8156480963516657),
#  ('html', 2.1967849075859833),
#  ('println', 2.6944455232746845),
#  ('客户端', 2.2915439713664387),
#  ('Object', 2.4152536256924617),
#  ('资源', 1.9894212147598633),
#  ('width', 2.543072326271329),
#  ('set', 2.191868031535487),
#  ('网络', 2.025702966054719),
#  ('android', 2.8894782058233366),
#  ('业务', 2.237352918754292),
#  ('php', 2.7579746685046613),
#  ('length', 2.2997055286977655),
#  ('web', 2.4781957456492587),
#  ('例子', 1.6955910974046529),
#  ('def', 2.8170942282016656),
#  ('记录', 1.8978171254360097),
#  ('进程', 2.69455220701085),
#  ('产品', 2.247603848612343),
#  ('app', 2.538680736413669),
#  ('效果', 1.749924650609047),
#  ('file', 2.42205472064704),
#  ('input', 2.5936612831652797),
#  ('mysql', 2.9859040083515933),
#  ('错误', 1.79902391423317),
#  ('框架', 2.0597816967023586),
#  ('性能', 1.9653613133579515),
#  ('item', 2.931987088435816),
#  ('链接', 1.599895239122834),
#  ('node', 2.895068807396034),
#  ('结构', 1.9173898830403615),
#  ('消息', 2.5753121444970835),
#  ('基础', 1.6673896622934448),
#  ('script', 2.737274188086386),
#  ('python', 2.1907070406930047),
#  ('str', 2.7735552334262907),
#  ('标签', 2.4017090387430096),
#  ('start', 2.3431187576629555),
#  ('架构', 2.3237136656532673),
#  ('工具', 1.9104494837245714),
#  ('request', 2.8896078654669544),
#  ('文档', 2.0420692219778567),
#  ('无法', 1.6349572310090081),
#  ('title', 2.5847313664135747),
#  ('height', 2.7049550033819134),
#  ('平台', 2.1847299670806293),
#  ('利用', 1.7207356429987377),
#  ('src', 2.4121920699656205),
#  ('color', 2.8264236712859674),
#  ('content', 2.5567357589241477),
#  ('mod', 2.8163709008645226),
#  ('style', 2.6818307378755373),
#  ('基本', 1.623303330020849),
#  ('time', 2.61029186339311),
#  ('ram', 2.935239123822193),
#  ('next', 2.961922043665108),
#  ('区块链', 3.283534507984263),
#  ('语言', 2.112793846940081),
#  ('body', 2.544448662681649),
#  ('count', 2.7292892282818952),
#  ('API', 2.2407356430407694),
#  ('容器', 2.6885953762916586),
#  ('defa', 2.257823065833978),
#  ('server', 2.6232220144210303),
#  ('字段', 2.5097975373864565),
#  ('left', 2.8867592295900932),
#  ('路径', 2.1206961869135026),
#  ('数字', 2.167261996646689),
#  ('final', 2.7745949146843865),
#  ('JavaScript', 2.549234681941586),
#  ('obj', 3.131335906640051),
#  ('arr', 3.617050150595802),
#  ('环境', 1.9191571016044566),
#  ('error', 2.535490650310412),
#  ('人工智能', 2.4146083082545635),
#  ('Android', 2.6990432325233136),
#  ('with', 2.2957596183513553),
#  ('逻辑', 2.023191910638446),
#  ('目标', 2.101174081389656),
#  ('github', 2.082662063356843),
#  ('css', 2.5957854511938754),
#  ('声明', 2.2304203653289365),
#  ('能力', 2.1139274647936492),
#  ('产生', 1.8519903613424986),
#  ('场景', 2.110054608640603),
#  ('map', 2.7538907150122034),
#  ('名称', 2.0923717242206283),
#  ('context', 2.9617826611295137),
#  ('Spring', 3.168853975003698),
#  ('args', 2.509265528152415),
#  ('关系', 1.9585409489792371),
#  ('格式', 2.1140468677788657),
#  ('语句', 2.476392783151841),
#  ('config', 2.7066813741171107),
#  ('Thread', 3.537131320283836),
#  ('字符', 2.651739237299907),
#  ('实际', 1.8010301954364933),
#  ('version', 2.6991504079159463),
#  ('func', 3.2398939552058126),
#  ('select', 2.9305000993142376),
#  ('image', 2.79609106950258),
#  ('age', 3.129356361288913),
#  ('num', 3.125737341053393),
#  ('区别', 1.9724876022304239),
#  ('state', 3.2089047943004383),
#  ('init', 2.5164716444741497),
#  ('table', 2.968775696620485),
#  ('作者', 1.7713082166343699),
#  ('条件', 2.243246246564749),
#  ('Override', 2.905817370702431),
#  ('run', 2.538498171374367),
#  ('json', 2.729952211731594),
#  ('方案', 2.2957596183513553),
#  ('tml', 2.1969146260969965),
#  ('核心', 2.035755510264419),
#  ('object', 2.5987862762519836),
#  ('原因', 1.804047184673186),
#  ('array', 3.0912010702196207),
#  ('try', 2.4739938786429536),
#  ('代表', 2.0591598237140043),
#  ('手机', 2.6420753606567655),
#  ('网站', 2.3567244097187343),
#  ('源码', 2.2435860012651263),
#  ('队列', 3.0913597122442256),
#  ('空间', 2.342968618784211),
#  ('规则', 2.3101836387990264),
#  ('document', 2.8057025347729243),
#  ('not', 2.2870620515812936),
#  ('事务', 3.464741515958985),
#  ('形式', 1.9499917136603884),
#  ('协议', 2.6460313428915705),
#  ('指向', 2.545183484061274),
#  ('while', 2.365131031638445),
#  ('数量', 2.1751007117952903),
#  ('catch', 2.689975052817223),
#  ('install', 2.5063445258542347),
#  ('NULL', 3.5044693869644887),
#  ('err', 3.5591763012039634),
#  ('机制', 2.2134612251211103),
#  ('i++', 2.4012315218218787),
#  ('view', 3.1071911774609062),
#  ('vue', 3.4013415777691103),
#  ('领域', 2.400436166653887),
#  ('List', 2.9372770295611135),
#  ('文本', 2.564199872697204),
#  ('usr', 3.118864461765631),
#  ('end', 2.795854914111236),
#  ('head', 2.9178824822542735),
#  ('企业', 2.737942488400856),
#  ('东西', 2.0465238203569203),
#  ('顺序', 2.2371503187198325),
#  ('方面', 2.0832987295626926),
#  ('spring', 3.421222079609439),
#  ('code', 2.7220252738236703),
#  ('地方', 1.8678269582913554),
#  ('概念', 2.0755704484078765),
#  ('len', 2.970742541873818),
#  ('++', 2.5945297156992337),
#  ('target', 2.9634565351428845),
#  ('CSS', 2.9806352172382025),
#  ('长度', 2.4884743936907183),
#  ('视频', 2.689762670953836),
#  ('插件', 2.8017755945209633),
#  ('redis', 3.702744871700685),
#  ('response', 3.259784935383458),
#  ('img', 3.2094402695475033),
#  ('智能', 2.8776208688078033),
#  ('ckage', 2.657274306781908),
#  ('background', 3.1242605994608796),
#  ('bin', 2.7647040922459545),
#  ('阶段', 2.5606474710928366),
#  ('特征', 2.957193902469162),
#  ('交易', 3.349086167950793),
#  ('method', 2.8115620433165933),
#  ('Node', 3.368363373871581),
#  ('max', 2.7870391062076445),
#  ('脚本', 2.6222290642848347),
#  ('大量', 2.059838249791586),
#  ('建议', 2.047193724920576),
#  ('right', 3.1118765402611577),
#  ('图像', 3.130840652812347),
#  ('日志', 2.854319827275294),
#  ('val', 3.393155405384595),
#  ('语法', 2.405617318892281),
#  ('top', 2.9594161256058795),
#  ('springframework', 3.844160226993576),
#  ('布局', 2.902922250901604),
#  ('特性', 2.216565484408628),
#  ('团队', 2.61560161038134),
#  ('样式', 2.8300822119521007),
#  ('原理', 2.2125384117934774),
#  ('事情', 2.1482387517016885),
#  ('add', 2.6976509966893274),
#  ('标准', 2.2372178475040023),
#  ('流程', 2.358628809456362),
#  ('排序', 2.796918052832835),
#  ('info', 3.039574709477416),
#  ('rent', 3.269027668351668),
#  ('boolean', 2.802963948790342),
#  ('步骤', 2.2195467049411914),
#  ('密码', 2.7324977280194958),
#  ('border', 3.398317817365875),
#  ('block', 3.129521173815038),
#  ('应用程序', 2.69071874475057),
#  ('配置文件', 2.581963000366993),
#  ('property', 3.517260679987431),
#  ('xml', 2.9302299750554366),
#  ('etc', 3.1180493993682386),
#  ('示例', 2.4563513514907966),
#  ('View', 3.30216497115857),
#  ('范围', 2.271916117302436),
#  ('case', 3.1361360482742917),
#  ('net', 2.5131735178494337),
#  ('赋值', 2.5352176872952055),
#  ('中国', 2.8335089684567554),
#  ('javascript', 2.133519977457198),
#  ('local', 3.152698534781413),
#  ('软件', 2.4787974562446258),
#  ('prototype', 3.5458410929001007),
#  ('PHP', 3.1667988278511667),
#  ('权限', 2.873401722997759),
#  ('MySQL', 3.161338995144685),
#  ('HTML', 2.774941715450824),
#  ('event', 3.3612726246627664),
#  ('message', 3.1961386634774027),
#  ('model', 3.3112165874654),
#  ('use', 2.6428855693298083),
#  ('React', 3.6108962850214237),
#  ('throws', 3.0754626276407304),
#  ('che', 3.133484845395777),
#  ('Vue', 3.5503501185756914),
#  ('SQL', 3.145973559873739),
#  ('速度', 2.3179135686325547),
#  ('hello', 3.025513146446639),
#  ('编码', 2.732830230100697),
#  ('Linux', 2.768143279402898),
#  ('extends', 2.7371628481096524),
#  ('number', 2.9846198532204253),
#  ('break', 2.8760845735370055),
#  ('then', 3.2534214476924883),
#  ('开发者', 2.5125507697309133),
#  ('window', 3.014874748241583),
#  ('ssword', 3.060121813888184),
#  ('Web', 2.801656836727344),
#  ('全部', 2.0778711511367454),
#  ('部署', 2.730394445016856),
#  ('官方', 2.2540387010464316),
#  ('require', 3.2994263152997525),
#  ('create', 2.7327193837889947),
#  ('CPU', 2.934832040568047),
#  ('名字', 2.3419182773267058),
#  ('session', 3.5153194029885544),
#  ('解决方案', 2.3418432951349413),
#  ('动画', 3.421222079609439),
#  ('App', 3.0376182034729147),
#  ('font', 3.406111751601867),
#  ('HTTP', 3.038069365222052),
#  ('URL', 2.927802134639789),
#  ('Promise', 3.983433908661495),
#  ('网页', 2.690187479796248),
#  ('position', 3.2327412424549493),
#  ('line', 3.024622277790838),
#  ('build', 2.9516598540345202),
#  ('Redis', 3.5757773720256685),
#  ('市场', 2.8898672351999606),
#  ('标记', 2.771940096942276),
#  ('行业', 2.7931431279773267),
#  ('call', 2.9585822131183597),
#  ('方向', 2.5670133416823884),
#  ('service', 3.0869272212132093),
#  ('策略', 2.756270993835102),
#  ('float', 3.157433071863525),
#  ('localhost', 2.923634621718132),
#  ('margin', 3.3740303005704146),
#  ('msg', 3.5655287555477835),
#  ('选项', 2.74006172403869),
#  ('区域', 2.830937800832748),
#  ('client', 3.2398939552058126),
#  ('echo', 3.387806082689595),
#  ('路由', 3.2796964683467835),
#  ('r2', 3.1038119804244273),
#  ('动态', 2.405297702429312),
#  ('视图', 3.1621901314629843),
#  ('artifactId', 4.0453175495779465),
#  ('分类', 2.8146851689782726),
#  ('read', 2.956916471478341),
#  ('hash', 3.4958733454946906),
#  ('文件夹', 2.7398384349900904),
#  ('机器学习', 3.211942952298187),
#  ('关键字', 2.674483937407793),
#  ('groupId', 4.0273578831797545),
#  ('效率', 2.3568005161155137),
#  ('全局', 2.608136690145127),
#  ('layout', 3.8221739982637373),
#  ('button', 3.3944435120461685),
#  ('机器', 2.7168844366882663),
#  ('指令', 3.077181780990609),
#  ('User', 3.3464208665267403),
#  ('long', 3.044709896717317),
#  ('体验', 2.486826160830046),
#  ('range', 3.0277437964904714),
#  ('返回值', 2.6935924628689323),
#  ('box', 3.6870787549562856),
#  ('foo', 3.725516815337237),
#  ('Integer', 3.404808536821419),
#  ('游戏', 3.2398939552058126),
#  ('模板', 2.9693372577752113),
#  ('all', 2.7276336901299163),
#  ('push', 2.979215972038295),
#  ('表达式', 3.0751503715882325),
#  ('思路', 2.426614617807889),
#  ('按钮', 2.795972984835737),
#  ('png', 2.9602507340838717),
#  ('super', 2.9556689836181747),
#  ('目的', 2.1795530789010953),
#  ('True', 3.1429620133446914),
#  ('nginx', 3.9982547727727127),
#  ('filter', 3.299230983723782),
#  ('char', 3.265622443721829),
#  ('that', 2.9693372577752113),
#  ('代理', 3.205342268266835),
#  ('字节', 3.2692171879201304),
#  ('指针', 3.2549150999492715),
#  ('date', 3.361688338657529),
#  ('个人', 2.3093848877127368),
#  ('close', 2.977798738240989),
#  ('dev', 3.266567176904991),
#  ('The', 2.7916136259437567),
#  ('txt', 3.281613646848121),
#  ('文字', 2.8938960924267922),
#  ('Person', 4.189020526054636),
#  ('update', 2.9479416097176423),
#  ('定位', 2.7319438034498567),
#  ('city', 3.704793752850629),
#  ('sql', 3.4487375163993983),
#  ('服务端', 3.106707735343683),
#  ('Exception', 3.0621228920592003),
#  ('普通', 2.409300269412361),
#  ('程序员', 2.7552501804985687),
#  ('options', 3.406763996434209),
#  ('bean', 4.077119392738818),
#  ('util', 3.1707415774517673),
#  ('传统', 2.552931885524576),
#  ('min', 2.9704613270238207),
#  ('DOM', 3.3790946709640997),
#  ('status', 3.17263274968223),
#  ('display', 3.223826419473291),
#  ('界面', 2.696367574053266),
#  ('Map', 3.3155747560116855),
#  ('sum', 3.487114856555011),
#  ('open', 2.9638754418026445),
#  ('resolve', 3.8198702289380977),
#  ('高度', 2.859465098085628),
#  ('子类', 3.2470981980576603),
#  ('show', 3.0486546750083336),
#  ('find', 3.2376876663902747),
#  ('href', 3.3002080233716087),
#  ('where', 3.322147830170534),
#  ('form', 3.455336698386844),
#  ('数据结构', 2.804391840513197),
#  ('比特币', 4.077970094619131),
#  ('username', 3.417477994187332),
#  ('action', 3.4356683804052173),
#  ('write', 3.0373175420154483),
#  ('git', 3.600283290738735),
#  ('Class', 3.3841848198122877),
#  ('dependency', 3.9120951008825586),
#  ('集群', 3.416159892063277),
#  ('世界', 2.6815147654678317),
#  ('api', 3.046832074260783),
#  ('conf', 3.3727682053250545),
#  ('开源', 2.66864511360472),
#  ('客户', 3.046680340704616),
#  ('阿里', 3.246727484429689),
#  ('template', 3.5416011563824563),
#  ('序列', 3.278356627013223),
#  ('first', 3.1474827410103567),
#  ('element', 3.5778397599698883),
#  ('编程', 2.704739416445647),
#  ('fmt', 4.263530934784298),
#  ('npm', 3.4421815982647965),
#  ('socket', 3.8519371047347604),
#  ('byte', 3.537131320283836),
#  ('原文', 2.203356815287797),
#  ('format', 3.184577841076327),
#  ('lang', 3.1604885826433953),
#  ('父类', 3.441055598821427),
#  ('dis', 3.9695928572496237),
#  ('throw', 3.182837802356453),
#  ('token', 3.836777643127388),
#  ('label', 3.719551990017066),
#  ('source', 3.1417933012991504),
#  ('微服务', 3.7764480674878196),
#  ('规范', 2.783884345163868),
#  ('toString', 3.091518379440116),
#  ('linux', 2.701726069352742),
#  ('绘制', 3.504949118324133),
#  ('中心', 2.9859040083515933),
#  ('child', 3.8700913967812007),
#  ('价值', 2.8745506348494216),
#  ('struct', 3.6194685314600834),
#  ('社区', 2.8549458837660358),
#  ('成本', 2.7579746685046613),
#  ('博客', 2.6556310898156745),
#  ('port', 3.2196691608875967),
#  ('None', 3.490892901190546),
#  ('JSON', 3.2048089823240566),
#  ('interface', 3.0526150762244306),
#  ('nil', 3.8914022469437253),
#  ('课程', 3.2584714911567336),
#  ('transform', 3.8188845216133385),
#  ('Server', 3.2301860302597873),
#  ('put', 3.376770317038605),
#  ('屏幕', 3.0757749812275277),
#  ('ppend', 3.31537624484478),
#  ('cache', 3.4503264396709286),
#  ('端口', 3.05353124669621),
#  ('深度学习', 3.5406061314247386),
#  ('颜色', 3.096449591214315),
#  ('dding', 3.43948132659705),
#  ('感觉', 2.499649645316108),
#  ('作用域', 3.5307099596170057),
#  ('关键', 2.4660671377985515),
#  ('join', 3.1954341900421386),
#  ('loader', 4.188545127899736),
#  ('query', 3.5112066598018066),
#  ('教程', 2.809166258749475),
#  ('utf', 2.9689160573477835),
#  ('链表', 3.9244275023752198),
#  ('新建', 2.66864511360472),
#  ('googlevideo', 11.146993521197391),
#  ('group', 3.4934986115361375),
#  ('#include', 3.709787154326098),
#  ('底层', 2.7014037486408458),
#  ('后台', 2.7806232195157365),
#  ('demo', 3.083773141954361),
#  ('特点', 2.555899521941619),
#  ('数据类型', 2.982625550565138),
#  ('单位', 2.853068888908514),
#  ('link', 3.2945544358398804),
#  ('export', 3.275110180926938),
#  ('次数', 2.8195091050091254),
#  ('values', 3.277591808620301),
#  ('字典', 3.441280697302963),
#  ('blog', 2.8057025347729243),
#  ('boot', 3.843150295919686),
#  ('计算机', 2.932122378972449),
#  ('互联网', 2.83228377839906),
#  ('queue', 3.9413583447870266),
#  ('lib', 3.2931945521917507),
#  ('科技', 3.153035973623825),
#  ('output', 3.43365563232552),
#  ('callback', 3.6100963916312203),
#  ('undefined', 3.3554707020466585),
#  ('header', 3.3974555625161598),
#  ('train', 4.576110558857806),
#  ('File', 3.4403806072331937),
#  ('用法', 2.6634605312737882),
#  ('经验', 2.7074375995083053),
#  ('react', 3.9092153292739473),
#  ('make', 3.294165708915646),
#  ('application', 3.110581832198767),
#  ('合约', 4.311808935050089),
#  ('temp', 3.969211105002193),
#  ('post', 3.1518554354986925),
#  ('row', 3.755578286522032),
#  ('Array', 3.354644597084353),
#  ('宽度', 3.343354320118761),
#  ('thread', 3.7639361745183093),
#  ('store', 3.926253986901254),
#  ('task', 4.00456145508737),
#  ('ctx', 4.547803525583459),
#  ('UTF', 3.0568977380164313),
#  ('个数', 2.893635675758654),
#  ('props', 4.096437443583582),
#  ('整体', 2.5829167438823024),
#  ('ArrayList', 3.59528130584608),
#  ('example', 3.4283080259989247),
#  ('意义', 2.5131735178494337),
#  ('答案', 2.762874684006495),
#  ('分布式', 3.05322576326631),
#  ('整数', 3.0974068344271672),
#  ('成员', 3.167997150343276),
#  ('lock', 3.8577243549296023),
#  ('meta', 3.2677020361151197),
#  ('master', 3.484995962295497),
#  ('数据集', 3.5160469403069317),
#  ('tch', 4.081807234266425),
#  ('Google', 3.077025372137549),
#  ('同学', 2.8196300020654292),
#  ('Date', 3.43790952881078),
#  ('center', 3.3901562600345483),
#  ('数值', 2.94519624080045),
#  ('加密', 3.4473775887192755),
#  ('instance', 3.4949227750809087),
#  ('细节', 2.6068653584986574),
#  ('样本', 3.8492252386660106),
#  ('SELECT', 3.804214331865545),
#  ('商品', 3.669955048877694),
#  ('手动', 2.6197509939281516),
#  ('线程池', 4.0951378982414965),
#  ('学生', 3.648400680479878),
#  ('篇文章', 2.5785370358436115),
#  ('cookie', 4.002586340876252),
#  ('iOS', 3.3122054138091963),
#  ('names', 3.210333365971964),
#  ('Math', 3.4793674296123998),
#  ('docker', 4.41180750756653),
#  ('current', 3.6055757084902003),
#  ('HashMap', 3.8536357632033407),
#  ('关联', 2.8982027875009777),
#  ('原生', 2.987046865618843),
#  ('一个对象', 2.863373076585902),
#  ('意思', 2.5767336088444606),
#  ('render', 3.721337704777301),
#  ('home', 3.510965259679934),
#  ('人类', 3.4113416611036937),
#  ('flex', 4.385999623610657),
#  ('using', 3.1006042791976576),
#  ('距离', 3.197372687433032),
#  ('auto', 3.2996216850376014),
#  ('命名', 2.9084565910256215),
#  ('优势', 2.6992575947963746),
#  ('背景', 2.838301604358493),
#  ('神经网络', 3.827459772050497),
#  ('主题', 2.971445925176363),
#  ('random', 3.448510733316444),
#  ('bind', 3.441280697302963),
#  ('canvas', 4.41299656834872),
#  ('处理器', 3.4198990364175486),
#  ('one', 3.2386063619073475),
#  ('Hello', 3.312007570302764),
#  ('缺点', 2.833386381879832),
#  ('you', 3.2509990110285143),
#  ('protected', 3.3187563057226304),
#  ('符号', 3.1555704009329664),
#  ('red', 3.467510961532451),
#  ('入门', 2.8241134994274857),
#  ('消费者', 3.4918396468233923),
#  ('process', 3.5213984490649364),
#  ('概率', 3.43343224351637),
#  ('plugin', 3.764869155459878),
#  ('rams', 3.7491256600468046),
#  ('案例', 2.984049646505047),
#  ('级别', 2.9631773614950636),
#  ('选择器', 4.096437443583582),
#  ('insert', 3.469593090682583),
#  ('tar', 3.868709703987985),
#  ('腾讯', 3.420560339208099),
#  ('env', 3.693431649554017),
#  ('有点', 2.533853988733944),
#  ('click', 3.480537430915869),
#  ('百度', 3.0934243520628497),
#  ('match', 3.720742112145043),
#  ('重点', 2.6269045266691275),
#  ('router', 4.136681653890161),
#  ('dict', 3.875637338205788),
#  ('double', 3.681624456950504),
#  ('equals', 3.586652673411431),
#  ('引擎', 3.273205418446284),
#  ('工程', 3.135472588306349),
#  ('Activity', 4.172514610172345),
#  ('tmp', 3.806482273871185),
#  ('delete', 3.255662763535502),
#  ('sudo', 3.7583564948223347),
#  ('机器人', 3.9799556442851705),
#  ('are', 3.1798866675004462),
#  ('原型', 3.68996143207501),
#  ('编辑', 2.9424583883031112),
#  ('constructor', 3.5793893470568228),
#  ('option', 3.9939418862599103),
#  ('synchronized', 3.876680635118366),
#  ('Windows', 3.168853975003698),
#  ('JVM', 3.4987304902954706),
#  ('全球', 3.1712569971006657),
#  ('alert', 3.691405892820167),
#  ('servlet', 4.375630867120808),
#  ('朋友', 2.7447623482508345),
#  ('计划', 2.9758179792458974),
#  ('程度', 2.689125795865968),
#  ('C++', 3.375715575879754),
#  ('remove', 3.210690827995431),
#  ('pre', 3.6665652151231827),
#  ('编译器', 3.3474451419414986),
#  ('运行时', 3.017081767455689),
#  ('base', 3.478666085340519),
#  ('host', 3.3702487834591115),
#  ('last', 3.479835265878243),
#  ('标题', 3.1170722005934084),
#  ('结点', 4.574011922200885),
#  ('dir', 3.679908209389648),
#  ('水平', 2.9265904212636613),
#  ('实例化', 3.241183208538459),
#  ('getName', 3.5614585387864297),
#  ('生命周期', 3.239157984611415),
#  ('角度', 2.819871840035169),
#  ('article', 3.043801768911604),
#  ('order', 3.5744905361770063),
#  ('async', 3.7964773493633923),
#  ('静态', 3.0398760504470004),
#  ('core', 3.515561856620485),
#  ('哈希', 3.835775136777762),
#  ('align', 3.7068468405347024),
#  ('handler', 3.8794680933692187),
#  ('常量', 3.3978865970055923),
#  ('load', 3.341926476938901),
#  ('角色', 3.3285632491267343),
#  ('优点', 2.861732387128442),
#  ('split', 3.405242753067929),
#  ('像素', 3.6905389660211814),
#  ('jpg', 3.486643603011888),
#  ('APP', 3.43387907104838),
#  ('回调函数', 3.5391154479188827),
#  ('价格', 3.3831222333771684),
#  ('FROM', 3.8725139624235196),
#  ('location', 3.606106494065295),
#  ('流量', 3.470519874808234),
#  ('区块', 4.377925761989147),
#  ('控件', 3.7342295037708273),
#  ('bool', 3.5112066598018066),
#  ('implements', 3.170398111880814),
#  ('False', 3.5668041032528497),
#  ('save', 3.413528888572337),
#  ('items', 3.6665652151231827),
#  ('人员', 3.042441121638413),
#  ('分支', 3.6202759598446845),
#  ('jQuery', 3.8384507236582),
#  ('std', 3.86767468578277),
#  ('Set', 3.482881548257424),
#  ('bar', 3.9247925324942576),
#  ('Test', 3.6316489500169546),
#  ('闭包', 4.0428494282098635),
#  ('Service', 3.6742085644357507),
#  ('硬件', 3.1560780581060652),
#  ('办法', 2.6767871210054897),
#  ('本质', 2.768947461191311),
#  ('电脑', 3.06629181649444),
#  ('小时', 3.014727786671769),
#  ('buffer', 4.052758675272635),
#  ('磁盘', 3.517503604803396),
#  ('分区', 4.1861715212785615),
#  ('xxx', 3.352994431693395),
#  ('bottom', 3.6870787549562856),
#  ('sleep', 3.5339154857251747),
#  ('jar', 3.798084291698582),
#  ('GET', 3.4473775887192755),
#  ('矩阵', 3.9117346755768008),
#  ('苹果', 3.6079664653733956),
#  ('信号', 3.60424997582884),
#  ('wait', 3.7418018555682786),
#  ('channel', 4.391224599213135),
#  ('proxy', 3.992768865597547),
#  ('Student', 4.7609563071476675),
#  ('address', 3.7676733324025653),
#  ('大数据', 3.40394066955063),
#  ('实体', 3.4289749149866284),
#  ('tcp', 4.146203376248064),
#  ('login', 3.793271190797759),
#  ('none', 3.3890873128456436),
#  ('专业', 3.1201699449797613),
#  ('爬虫', 3.8428138787592383),
#  ('setTimeout', 3.783080019791571),
#  ('资料', 2.861480212117649),
#  ('can', 3.236036138351802),
#  ('入口', 3.1640651852809065),
#  ('container', 3.8058337654178476),
#  ('原则', 3.0951746906432263),
#  ('内核', 3.552109133980871),
#  ('charset', 3.1798866675004462),
#  ('单词', 3.723126614020025),
#  ('now', 3.6637491051235407),
#  ('Type', 3.383547132470028),
#  ('column', 4.0407973035414155),
#  ('encoding', 3.3736094251433264),
#  ('空格', 3.2893193293611143),
#  ('score', 4.397647978962895),
#  ('replace', 3.581200238768876),
#  ('filename', 3.7586656616202836),
#  ('await', 4.25283019573472),
#  ('机会', 2.9356463728606053),
#  ('ref', 3.781496989541718),
#  ('工程师', 3.2452460026772463),
#  ('send', 3.6940111917319305),
#  ('交流', 2.8374396945593974),
#  ('二进制', 3.362936518557462),
#  ('美国', 3.4399308658269176),
#  ('component', 3.9931597196185478),
#  ('sort', 3.5840525679424267),
#  ('时代', 3.1300157744351282),
#  ('中间件', 3.8482101819048586),
#  ('镜像', 3.8878773931002897),
#  ('思想', 2.9480790762104014),
#  ('keys', 3.6008112738555407),
#  ('人们', 3.1083201187952283),
#  ('容量', 3.68047996469396),
#  ('IOException', 3.877376771589221),
#  ('TCP', 3.771737743187636),
#  ('终端', 3.303537116821275),
#  ('mode', 3.5458410929001007),
#  ('深度', 3.1516869009065687),
#  ('printStackTrace', 3.6648745976452752),
#  ('before', 3.5463410929105175),
#  ('用户名', 3.3033409807021803),
#  ('动作', 3.2221976072409553),
#  ('sys', 3.957071350451583),
#  ('promise', 4.427980366812131),
#  ('内置', 2.996237050921839),
#  ('tag', 3.9167924898271815),
#  ('谷歌', 3.502074176238534),
#  ('flag', 3.958580784700437),
#  ('评论', 3.2376876663902747),
#  ('schema', 4.432216379197737),
#  ('plt', 4.918482517606208),
#  ('表单', 3.668541221411872),
#  ('理论', 3.0272972682401407),
#  ('装饰', 4.22287288812899),
#  ('官网', 2.950418902479199),
#  ('嵌套', 3.2554757952260855),
#  ('Context', 3.8970679844794027),
#  ('copy', 3.5138659143605713),
#  ('小米', 4.263018770880657),
#  ('entry', 3.9896475208861952),
#  ('域名', 3.6069032010520656),
#  ('调度', 3.6722213387995204),
#  ('备份', 3.852955953523863),
#  ('search', 3.693431649554017),
#  ('scope', 4.061510554431527),
#  ('以太坊', 4.429793603936312),
#  ('person', 4.38253141204173),
#  ('req', 4.368777613570239),
#  ('typeof', 3.712440848939564),
#  ('will', 3.4314239866771823),
#  ('序列化', 3.8016286807805217),
#  ('word', 4.089525968986926),
#  ('订单', 4.00298105175566),
#  ('conn', 4.606685283135897),
#  ('POST', 3.6186617544901436),
#  ('区分', 2.8868885371483004),
#  ('Error', 3.4207808706898617),
#  ('reject', 4.487058781241903),
#  ('via', 3.8522766056716486),
#  ('历史', 3.117235000756568),
#  ('timeout', 3.692852443050712),
#  ('h2', 3.8471961544392297),
#  ('权重', 3.8492252386660106),
#  ('文件名', 3.298450038740711),
#  ('证明', 3.2094402695475033),
#  ('老师', 3.4399308658269176),
#  ('Println', 4.586670319072808),
#  ('world', 3.5253085224727796),
#  ('btn', 4.332450623937432),
#  ('整理', 2.928745594511645),
#  ('向量', 4.093407794003714),
#  ('bytes', 3.871821201744619),
#  ('tree', 3.883313579667225),
#  ('rse', 3.5806825064249272),
#  ('files', 3.606371992540238),
#  ('properties', 3.6856405266053938),
#  ('孩子', 4.1187920891393865),
#  ('yum', 3.9865358886594993),
#  ('tab', 4.172514610172345),
#  ('命令行', 3.216967186803866),
#  ('论文', 3.8391207404336845),
#  ('来源', 2.9256489915659945),
#  ('账户', 3.7811806839879183),
#  ('知识点', 3.1359701420109496),
#  ('ret', 4.470539981230926),
#  ('printf', 3.9657818770274544),
#  ('after', 3.486879202023462),
#  ('Name', 3.8110336471375996),
#  ('success', 3.6640303595199946),
#  ('Session', 4.12590955690825),
#  ('ES6', 3.7225299552911073),
#  ('shape', 4.359148538887811),
#  ('源代码', 3.1412928425348476),
#  ('公众号', 3.0615067490945447),
#  ('total', 3.9638818194541092),
#  ('system', 3.562474540905832),
#  ('华为', 4.200498413899323),
#  ('field', 4.1430193844747105),
#  ('尺寸', 3.57551987234612),
#  ('金融', 3.790713644646642),
#  ('风险', 3.3484704675721844),
#  ('表格', 3.5056691471563926),
#  ('student', 4.70604698056447),
#  ('中文', 3.2432125423222447),
#  ('风格', 3.352994431693395),
#  ('commit', 3.8892858440373477),
#  ('标识', 3.1982550663837803),
#  ('project', 3.7884811449153823),
#  ('baidu', 3.736343988775543),
#  ('城市', 3.7375542763665464),
#  ('运算符', 3.8492252386660106),
#  ('inline', 3.6940111917319305),
#  ('yield', 4.379650395931998),
#  ('全面', 3.0480467722540507),
#  ('images', 3.949932488647375),
#  ('拷贝', 3.4045914993816084),
#  ('fun', 4.475593687501694),
#  ('connection', 4.018096693571716),
#  ('技巧', 3.1956102618799034),
#  ('Docker', 4.169712179566643),
#  ('admin', 3.984208502038722),
#  ('cout', 4.675420322985478),
#  ('仓库', 3.6456351919916945),
#  ('字体', 3.854996770558716),
#  ('author', 3.7402827910197503),
#  ('maven', 4.181441143489037),
#  ('debug', 3.585871931667153),
#  ('stack', 4.1308323683714665),
#  ('属性值', 3.491602876371238),
#  ('include', 3.6308322901103987),
#  ('offset', 4.045729496030734),
#  ('构造方法', 3.8218445632418154),
#  ('This', 3.43365563232552),
#  ('Data', 3.583014415759906),
#  ('iPhone', 3.899912936611634),
#  ('类别', 3.7177694583507828),
#  ('设计模式', 3.584312274475506),
#  ('联系', 2.92055378075742),
#  ('体系', 3.343150217658618),
#  ('jianshu', 2.7861033241765543),
#  ('2d', 3.6055757084902003),
#  ('中断', 3.7059664296194326),
#  ('connect', 3.670521140033485),
#  ('arguments', 3.8836639037205543),
#  ('开发人员', 3.3002080233716087),
#  ('Log', 4.128144194709667),
#  ('Bean', 4.256893177453974),
#  ('Model', 3.8465207069295917),
#  ('Component', 3.9795699162186713),
#  ('solid', 3.958580784700437),
#  ('exports', 4.119679007157615),
#  ('迭代器', 4.275902226586845),
#  ('logger', 4.438299123013506),
#  ('support', 3.7777079101741404),
#  ('dom', 3.8826132995265628),
#  ('一致性', 3.617855627884619),
#  ('明白', 2.9626192479044637),
#  ('XML', 3.7654916266906837),
#  ('users', 4.085659154286953),
#  ('global', 3.6191995334759466),
#  ('员工', 3.921876015662062),
#  ('两者', 2.9932122016583182),
#  ('专门', 2.919083683599908),
#  ('cat', 3.8444970974700645),
#  ('Chrome', 3.5786142533608682),
#  ('规定', 3.2080129722489987),
#  ('省略', 3.2753008568737454),
#  ('DEFAULT', 4.0758446953068175),
#  ('price', 4.609577548348043),
#  ('worker', 4.525587869433256),
#  ('grid', 4.959756619571331),
#  ('习惯', 3.161509164463568),
#  ('pop', 3.730615042004463),
#  ('execute', 3.8580658266761336),
#  ('into', 3.5662937689728276),
#  ('INSERT', 4.429793603936312),
#  ('前言', 2.769292308599752),
#  ('volatile', 4.477495431339511),
#  ('经历', 3.153204735754004),
#  ('维度', 3.675061442952268),
#  ('笔记', 3.1424609694928733),
#  ('Cookie', 4.527587203654738),
#  ('单元', 3.6316489500169546),
#  ('command', 3.8218445632418154),
#  ('abc', 3.957071350451583),
#  ('xmlns', 4.09817280193665),
#  ('has', 3.4341025597072607),
#  ('读者', 3.355057564259332),
#  ('基本上', 2.9986924576584775),
#  ('校验', 3.6742085644357507),
#  ('质量', 3.4210014508164863),
#  ('Content', 3.666283246983714),
#  ('level', 3.9310185185459243),
#  ('国家', 3.489474461236412),
#  ('物理', 3.5066299927743945),
#  ('stop', 3.6058410660610822),
#  ('上线', 3.273776466334649),
#  ('Boot', 4.288953834461187),
#  ('##', 4.150312033020852),
#  ('finally', 3.717472678410928),
#  ('层面', 3.2243699469801044),
#  ...]

# %%
len(keywords_list_with_idf)
# Out:
# 1234544

# %%
def func(data):
    for index in range(len(data)):
        data[index] = list(data[index])
        data[index].append(index)
        data[index][1] = float(data[index][1])

# %%
func(keywords_list_with_idf)

# %%
keywords_list_with_idf
# Out:
# [['&#', 1.417829594344155, 0],
#  ['pa', 0.6651385256756351, 1],
#  ['ul', 0.8070591229443697, 2],
#  ['代码', 0.7368239176481552, 3],
#  ['方法', 0.7506253985501485, 4],
#  ['数据', 0.9375297590538404, 5],
#  ['return', 1.1584986818528347, 6],
#  ['对象', 1.2765716628665975, 7],
#  ['name', 1.3833429138490618, 8],
#  ['this', 1.6247297855214076, 9],
#  ['public', 1.7540399682870398, 10],
#  ['int', 1.6612207991983439, 11],
#  ['new', 1.3335127364488795, 12],
#  ['问题', 0.8151384673357938, 13],
#  ['函数', 1.4147095597213706, 14],
#  ['.a', 1.2475641921221166, 15],
#  ['class', 1.3562548221032567, 16],
#  ['文件', 1.2163286406564702, 17],
#  ['amp', 1.5313880611157102, 18],
#  ['com', 0.9229090811983397, 19],
#  ['元素', 1.7964130603067618, 20],
#  ['function', 1.7912981813618367, 21],
#  ['用户', 1.2794959063944176, 22],
#  ['String', 1.9240331178651056, 23],
#  ['内容', 0.7449604375370865, 24],
#  ['时候', 0.9169217434065458, 25],
#  ['var', 1.8734436358233233, 26],
#  ['参数', 1.2650616316269794, 27],
#  ['for', 1.254061482600779, 28],
#  ['属性', 1.5263663508338299, 29],
#  ['方式', 0.9338361580079647, 30],
#  ['void', 1.841161167761987, 31],
#  ['data', 1.8557185317252085, 32],
#  ['__', 2.546746774645867, 33],
#  ['the', 1.9411633046990937, 34],
#  ['技术', 1.5675408705788416, 35],
#  ['value', 1.873866161122443, 36],
#  ['结果', 1.158246124710439, 37],
#  ['信息', 1.1976725523180902, 38],
#  ['log', 2.0027395343490673, 39],
#  ['定义', 1.281986955479544, 40],
#  ['类型', 1.4151250023220814, 41],
#  ['项目', 1.430106667940106, 42],
#  ['时间', 1.2046218506112962, 43],
#  ['import', 1.9502451027406746, 44],
#  ['div', 2.5311321579844517, 45],
#  ['线程', 2.574744124033075, 46],
#  ['系统', 1.3915710367771266, 47],
#  ['情况', 1.0592279935689197, 48],
#  ['print', 2.3394468287742134, 49],
#  ['节点', 2.3044612661522734, 50],
#  ['.h', 1.4393383874831644, 51],
#  ['http', 1.4940207167716042, 52],
#  ['self', 2.914287511336415, 53],
#  ['功能', 1.2030120279447727, 54],
#  ['key', 2.1520765775202793, 55],
#  ['true', 1.6357340737374313, 56],
#  ['res', 2.169783907068485, 57],
#  ['type', 1.8571490481086088, 58],
#  ['java', 1.7717745060389738, 59],
#  ['数组', 2.0402929239809673, 60],
#  ['数据库', 1.8724584371792108, 61],
#  ['组件', 2.280270854003292, 62],
#  ['过程', 1.269644626270957, 63],
#  ['console', 2.4320156129338333, 64],
#  ['https', 1.2886340962790102, 65],
#  ['index', 2.056845334549614, 66],
#  ['页面', 1.816074026262823, 67],
#  ['状态', 1.7526247166355668, 68],
#  ['程序', 1.6171091036206826, 69],
#  ['get', 1.8455335558537238, 70],
#  ['test', 2.22380203051133, 71],
#  ['服务器', 1.96659702559428, 72],
#  ['static', 2.0184056510934667, 73],
#  ['from', 1.8911063342652372, 74],
#  ['命令', 2.020360898294693, 75],
#  ['private', 2.232367393370253, 76],
#  ['else', 1.7483495207497055, 77],
#  ['字符串', 1.9605360896845399, 78],
#  ['org', 2.2521176026854404, 79],
#  ['模块', 2.0921964649825573, 80],
#  ['out', 2.2857142946828337, 81],
#  ['模型', 2.2947576859695347, 82],
#  ['总结', 1.6396645174491273, 83],
#  ['System', 2.4040202571458136, 84],
#  ['算法', 2.035203572950485, 85],
#  ['目录', 1.899164704810216, 86],
#  ['false', 1.8536916285068603, 87],
#  ['消耗', 3.1328231414841228, 88],
#  ['list', 2.2459675218001025, 89],
#  ['部分', 1.4123685057710609, 90],
#  ['Java', 2.0721865445164034, 91],
#  ['实例', 1.937703700857387, 92],
#  ['www', 1.499075867197057, 93],
#  ['const', 2.5684230501062495, 94],
#  ['root', 2.585879142723225, 95],
#  ['任务', 2.259547977428733, 96],
#  ['size', 2.236340328800421, 97],
#  ['大家', 1.475627199007823, 98],
#  ['text', 2.1484859093895508, 99],
#  ['url', 2.28791420331586, 100],
#  ['版本', 1.6448794588661733, 101],
#  ['浏览器', 2.0286039779691163, 102],
#  ['内存', 2.08817395686245, 103],
#  ['main', 1.876310920215046, 104],
#  ['Python', 2.3889740436146356, 105],
#  ['事件', 2.2787914074690474, 106],
#  ['文章', 1.5470125914600148, 107],
#  ['user', 2.414043996900961, 108],
#  ['and', 1.9691246893681704, 109],
#  ['string', 2.406416807262336, 110],
#  ['模式', 1.863031009350594, 111],
#  ['列表', 1.9649497483763214, 112],
#  ['图片', 2.1460170771270457, 113],
#  ['地址', 1.7123502701871516, 114],
#  ['公司', 2.073389672794679, 115],
#  ['索引', 2.624713290732596, 116],
#  ['let', 2.8156480963516657, 117],
#  ['html', 2.1967849075859833, 118],
#  ['println', 2.6944455232746845, 119],
#  ['客户端', 2.2915439713664387, 120],
#  ['Object', 2.4152536256924617, 121],
#  ['资源', 1.9894212147598633, 122],
#  ['width', 2.543072326271329, 123],
#  ['set', 2.191868031535487, 124],
#  ['网络', 2.025702966054719, 125],
#  ['android', 2.8894782058233366, 126],
#  ['业务', 2.237352918754292, 127],
#  ['php', 2.7579746685046613, 128],
#  ['length', 2.2997055286977655, 129],
#  ['web', 2.4781957456492587, 130],
#  ['例子', 1.6955910974046529, 131],
#  ['def', 2.8170942282016656, 132],
#  ['记录', 1.8978171254360097, 133],
#  ['进程', 2.69455220701085, 134],
#  ['产品', 2.247603848612343, 135],
#  ['app', 2.538680736413669, 136],
#  ['效果', 1.749924650609047, 137],
#  ['file', 2.42205472064704, 138],
#  ['input', 2.5936612831652797, 139],
#  ['mysql', 2.9859040083515933, 140],
#  ['错误', 1.79902391423317, 141],
#  ['框架', 2.0597816967023586, 142],
#  ['性能', 1.9653613133579515, 143],
#  ['item', 2.931987088435816, 144],
#  ['链接', 1.599895239122834, 145],
#  ['node', 2.895068807396034, 146],
#  ['结构', 1.9173898830403615, 147],
#  ['消息', 2.5753121444970835, 148],
#  ['基础', 1.6673896622934448, 149],
#  ['script', 2.737274188086386, 150],
#  ['python', 2.1907070406930047, 151],
#  ['str', 2.7735552334262907, 152],
#  ['标签', 2.4017090387430096, 153],
#  ['start', 2.3431187576629555, 154],
#  ['架构', 2.3237136656532673, 155],
#  ['工具', 1.9104494837245714, 156],
#  ['request', 2.8896078654669544, 157],
#  ['文档', 2.0420692219778567, 158],
#  ['无法', 1.6349572310090081, 159],
#  ['title', 2.5847313664135747, 160],
#  ['height', 2.7049550033819134, 161],
#  ['平台', 2.1847299670806293, 162],
#  ['利用', 1.7207356429987377, 163],
#  ['src', 2.4121920699656205, 164],
#  ['color', 2.8264236712859674, 165],
#  ['content', 2.5567357589241477, 166],
#  ['mod', 2.8163709008645226, 167],
#  ['style', 2.6818307378755373, 168],
#  ['基本', 1.623303330020849, 169],
#  ['time', 2.61029186339311, 170],
#  ['ram', 2.935239123822193, 171],
#  ['next', 2.961922043665108, 172],
#  ['区块链', 3.283534507984263, 173],
#  ['语言', 2.112793846940081, 174],
#  ['body', 2.544448662681649, 175],
#  ['count', 2.7292892282818952, 176],
#  ['API', 2.2407356430407694, 177],
#  ['容器', 2.6885953762916586, 178],
#  ['defa', 2.257823065833978, 179],
#  ['server', 2.6232220144210303, 180],
#  ['字段', 2.5097975373864565, 181],
#  ['left', 2.8867592295900932, 182],
#  ['路径', 2.1206961869135026, 183],
#  ['数字', 2.167261996646689, 184],
#  ['final', 2.7745949146843865, 185],
#  ['JavaScript', 2.549234681941586, 186],
#  ['obj', 3.131335906640051, 187],
#  ['arr', 3.617050150595802, 188],
#  ['环境', 1.9191571016044566, 189],
#  ['error', 2.535490650310412, 190],
#  ['人工智能', 2.4146083082545635, 191],
#  ['Android', 2.6990432325233136, 192],
#  ['with', 2.2957596183513553, 193],
#  ['逻辑', 2.023191910638446, 194],
#  ['目标', 2.101174081389656, 195],
#  ['github', 2.082662063356843, 196],
#  ['css', 2.5957854511938754, 197],
#  ['声明', 2.2304203653289365, 198],
#  ['能力', 2.1139274647936492, 199],
#  ['产生', 1.8519903613424986, 200],
#  ['场景', 2.110054608640603, 201],
#  ['map', 2.7538907150122034, 202],
#  ['名称', 2.0923717242206283, 203],
#  ['context', 2.9617826611295137, 204],
#  ['Spring', 3.168853975003698, 205],
#  ['args', 2.509265528152415, 206],
#  ['关系', 1.9585409489792371, 207],
#  ['格式', 2.1140468677788657, 208],
#  ['语句', 2.476392783151841, 209],
#  ['config', 2.7066813741171107, 210],
#  ['Thread', 3.537131320283836, 211],
#  ['字符', 2.651739237299907, 212],
#  ['实际', 1.8010301954364933, 213],
#  ['version', 2.6991504079159463, 214],
#  ['func', 3.2398939552058126, 215],
#  ['select', 2.9305000993142376, 216],
#  ['image', 2.79609106950258, 217],
#  ['age', 3.129356361288913, 218],
#  ['num', 3.125737341053393, 219],
#  ['区别', 1.9724876022304239, 220],
#  ['state', 3.2089047943004383, 221],
#  ['init', 2.5164716444741497, 222],
#  ['table', 2.968775696620485, 223],
#  ['作者', 1.7713082166343699, 224],
#  ['条件', 2.243246246564749, 225],
#  ['Override', 2.905817370702431, 226],
#  ['run', 2.538498171374367, 227],
#  ['json', 2.729952211731594, 228],
#  ['方案', 2.2957596183513553, 229],
#  ['tml', 2.1969146260969965, 230],
#  ['核心', 2.035755510264419, 231],
#  ['object', 2.5987862762519836, 232],
#  ['原因', 1.804047184673186, 233],
#  ['array', 3.0912010702196207, 234],
#  ['try', 2.4739938786429536, 235],
#  ['代表', 2.0591598237140043, 236],
#  ['手机', 2.6420753606567655, 237],
#  ['网站', 2.3567244097187343, 238],
#  ['源码', 2.2435860012651263, 239],
#  ['队列', 3.0913597122442256, 240],
#  ['空间', 2.342968618784211, 241],
#  ['规则', 2.3101836387990264, 242],
#  ['document', 2.8057025347729243, 243],
#  ['not', 2.2870620515812936, 244],
#  ['事务', 3.464741515958985, 245],
#  ['形式', 1.9499917136603884, 246],
#  ['协议', 2.6460313428915705, 247],
#  ['指向', 2.545183484061274, 248],
#  ['while', 2.365131031638445, 249],
#  ['数量', 2.1751007117952903, 250],
#  ['catch', 2.689975052817223, 251],
#  ['install', 2.5063445258542347, 252],
#  ['NULL', 3.5044693869644887, 253],
#  ['err', 3.5591763012039634, 254],
#  ['机制', 2.2134612251211103, 255],
#  ['i++', 2.4012315218218787, 256],
#  ['view', 3.1071911774609062, 257],
#  ['vue', 3.4013415777691103, 258],
#  ['领域', 2.400436166653887, 259],
#  ['List', 2.9372770295611135, 260],
#  ['文本', 2.564199872697204, 261],
#  ['usr', 3.118864461765631, 262],
#  ['end', 2.795854914111236, 263],
#  ['head', 2.9178824822542735, 264],
#  ['企业', 2.737942488400856, 265],
#  ['东西', 2.0465238203569203, 266],
#  ['顺序', 2.2371503187198325, 267],
#  ['方面', 2.0832987295626926, 268],
#  ['spring', 3.421222079609439, 269],
#  ['code', 2.7220252738236703, 270],
#  ['地方', 1.8678269582913554, 271],
#  ['概念', 2.0755704484078765, 272],
#  ['len', 2.970742541873818, 273],
#  ['++', 2.5945297156992337, 274],
#  ['target', 2.9634565351428845, 275],
#  ['CSS', 2.9806352172382025, 276],
#  ['长度', 2.4884743936907183, 277],
#  ['视频', 2.689762670953836, 278],
#  ['插件', 2.8017755945209633, 279],
#  ['redis', 3.702744871700685, 280],
#  ['response', 3.259784935383458, 281],
#  ['img', 3.2094402695475033, 282],
#  ['智能', 2.8776208688078033, 283],
#  ['ckage', 2.657274306781908, 284],
#  ['background', 3.1242605994608796, 285],
#  ['bin', 2.7647040922459545, 286],
#  ['阶段', 2.5606474710928366, 287],
#  ['特征', 2.957193902469162, 288],
#  ['交易', 3.349086167950793, 289],
#  ['method', 2.8115620433165933, 290],
#  ['Node', 3.368363373871581, 291],
#  ['max', 2.7870391062076445, 292],
#  ['脚本', 2.6222290642848347, 293],
#  ['大量', 2.059838249791586, 294],
#  ['建议', 2.047193724920576, 295],
#  ['right', 3.1118765402611577, 296],
#  ['图像', 3.130840652812347, 297],
#  ['日志', 2.854319827275294, 298],
#  ['val', 3.393155405384595, 299],
#  ['语法', 2.405617318892281, 300],
#  ['top', 2.9594161256058795, 301],
#  ['springframework', 3.844160226993576, 302],
#  ['布局', 2.902922250901604, 303],
#  ['特性', 2.216565484408628, 304],
#  ['团队', 2.61560161038134, 305],
#  ['样式', 2.8300822119521007, 306],
#  ['原理', 2.2125384117934774, 307],
#  ['事情', 2.1482387517016885, 308],
#  ['add', 2.6976509966893274, 309],
#  ['标准', 2.2372178475040023, 310],
#  ['流程', 2.358628809456362, 311],
#  ['排序', 2.796918052832835, 312],
#  ['info', 3.039574709477416, 313],
#  ['rent', 3.269027668351668, 314],
#  ['boolean', 2.802963948790342, 315],
#  ['步骤', 2.2195467049411914, 316],
#  ['密码', 2.7324977280194958, 317],
#  ['border', 3.398317817365875, 318],
#  ['block', 3.129521173815038, 319],
#  ['应用程序', 2.69071874475057, 320],
#  ['配置文件', 2.581963000366993, 321],
#  ['property', 3.517260679987431, 322],
#  ['xml', 2.9302299750554366, 323],
#  ['etc', 3.1180493993682386, 324],
#  ['示例', 2.4563513514907966, 325],
#  ['View', 3.30216497115857, 326],
#  ['范围', 2.271916117302436, 327],
#  ['case', 3.1361360482742917, 328],
#  ['net', 2.5131735178494337, 329],
#  ['赋值', 2.5352176872952055, 330],
#  ['中国', 2.8335089684567554, 331],
#  ['javascript', 2.133519977457198, 332],
#  ['local', 3.152698534781413, 333],
#  ['软件', 2.4787974562446258, 334],
#  ['prototype', 3.5458410929001007, 335],
#  ['PHP', 3.1667988278511667, 336],
#  ['权限', 2.873401722997759, 337],
#  ['MySQL', 3.161338995144685, 338],
#  ['HTML', 2.774941715450824, 339],
#  ['event', 3.3612726246627664, 340],
#  ['message', 3.1961386634774027, 341],
#  ['model', 3.3112165874654, 342],
#  ['use', 2.6428855693298083, 343],
#  ['React', 3.6108962850214237, 344],
#  ['throws', 3.0754626276407304, 345],
#  ['che', 3.133484845395777, 346],
#  ['Vue', 3.5503501185756914, 347],
#  ['SQL', 3.145973559873739, 348],
#  ['速度', 2.3179135686325547, 349],
#  ['hello', 3.025513146446639, 350],
#  ['编码', 2.732830230100697, 351],
#  ['Linux', 2.768143279402898, 352],
#  ['extends', 2.7371628481096524, 353],
#  ['number', 2.9846198532204253, 354],
#  ['break', 2.8760845735370055, 355],
#  ['then', 3.2534214476924883, 356],
#  ['开发者', 2.5125507697309133, 357],
#  ['window', 3.014874748241583, 358],
#  ['ssword', 3.060121813888184, 359],
#  ['Web', 2.801656836727344, 360],
#  ['全部', 2.0778711511367454, 361],
#  ['部署', 2.730394445016856, 362],
#  ['官方', 2.2540387010464316, 363],
#  ['require', 3.2994263152997525, 364],
#  ['create', 2.7327193837889947, 365],
#  ['CPU', 2.934832040568047, 366],
#  ['名字', 2.3419182773267058, 367],
#  ['session', 3.5153194029885544, 368],
#  ['解决方案', 2.3418432951349413, 369],
#  ['动画', 3.421222079609439, 370],
#  ['App', 3.0376182034729147, 371],
#  ['font', 3.406111751601867, 372],
#  ['HTTP', 3.038069365222052, 373],
#  ['URL', 2.927802134639789, 374],
#  ['Promise', 3.983433908661495, 375],
#  ['网页', 2.690187479796248, 376],
#  ['position', 3.2327412424549493, 377],
#  ['line', 3.024622277790838, 378],
#  ['build', 2.9516598540345202, 379],
#  ['Redis', 3.5757773720256685, 380],
#  ['市场', 2.8898672351999606, 381],
#  ['标记', 2.771940096942276, 382],
#  ['行业', 2.7931431279773267, 383],
#  ['call', 2.9585822131183597, 384],
#  ['方向', 2.5670133416823884, 385],
#  ['service', 3.0869272212132093, 386],
#  ['策略', 2.756270993835102, 387],
#  ['float', 3.157433071863525, 388],
#  ['localhost', 2.923634621718132, 389],
#  ['margin', 3.3740303005704146, 390],
#  ['msg', 3.5655287555477835, 391],
#  ['选项', 2.74006172403869, 392],
#  ['区域', 2.830937800832748, 393],
#  ['client', 3.2398939552058126, 394],
#  ['echo', 3.387806082689595, 395],
#  ['路由', 3.2796964683467835, 396],
#  ['r2', 3.1038119804244273, 397],
#  ['动态', 2.405297702429312, 398],
#  ['视图', 3.1621901314629843, 399],
#  ['artifactId', 4.0453175495779465, 400],
#  ['分类', 2.8146851689782726, 401],
#  ['read', 2.956916471478341, 402],
#  ['hash', 3.4958733454946906, 403],
#  ['文件夹', 2.7398384349900904, 404],
#  ['机器学习', 3.211942952298187, 405],
#  ['关键字', 2.674483937407793, 406],
#  ['groupId', 4.0273578831797545, 407],
#  ['效率', 2.3568005161155137, 408],
#  ['全局', 2.608136690145127, 409],
#  ['layout', 3.8221739982637373, 410],
#  ['button', 3.3944435120461685, 411],
#  ['机器', 2.7168844366882663, 412],
#  ['指令', 3.077181780990609, 413],
#  ['User', 3.3464208665267403, 414],
#  ['long', 3.044709896717317, 415],
#  ['体验', 2.486826160830046, 416],
#  ['range', 3.0277437964904714, 417],
#  ['返回值', 2.6935924628689323, 418],
#  ['box', 3.6870787549562856, 419],
#  ['foo', 3.725516815337237, 420],
#  ['Integer', 3.404808536821419, 421],
#  ['游戏', 3.2398939552058126, 422],
#  ['模板', 2.9693372577752113, 423],
#  ['all', 2.7276336901299163, 424],
#  ['push', 2.979215972038295, 425],
#  ['表达式', 3.0751503715882325, 426],
#  ['思路', 2.426614617807889, 427],
#  ['按钮', 2.795972984835737, 428],
#  ['png', 2.9602507340838717, 429],
#  ['super', 2.9556689836181747, 430],
#  ['目的', 2.1795530789010953, 431],
#  ['True', 3.1429620133446914, 432],
#  ['nginx', 3.9982547727727127, 433],
#  ['filter', 3.299230983723782, 434],
#  ['char', 3.265622443721829, 435],
#  ['that', 2.9693372577752113, 436],
#  ['代理', 3.205342268266835, 437],
#  ['字节', 3.2692171879201304, 438],
#  ['指针', 3.2549150999492715, 439],
#  ['date', 3.361688338657529, 440],
#  ['个人', 2.3093848877127368, 441],
#  ['close', 2.977798738240989, 442],
#  ['dev', 3.266567176904991, 443],
#  ['The', 2.7916136259437567, 444],
#  ['txt', 3.281613646848121, 445],
#  ['文字', 2.8938960924267922, 446],
#  ['Person', 4.189020526054636, 447],
#  ['update', 2.9479416097176423, 448],
#  ['定位', 2.7319438034498567, 449],
#  ['city', 3.704793752850629, 450],
#  ['sql', 3.4487375163993983, 451],
#  ['服务端', 3.106707735343683, 452],
#  ['Exception', 3.0621228920592003, 453],
#  ['普通', 2.409300269412361, 454],
#  ['程序员', 2.7552501804985687, 455],
#  ['options', 3.406763996434209, 456],
#  ['bean', 4.077119392738818, 457],
#  ['util', 3.1707415774517673, 458],
#  ['传统', 2.552931885524576, 459],
#  ['min', 2.9704613270238207, 460],
#  ['DOM', 3.3790946709640997, 461],
#  ['status', 3.17263274968223, 462],
#  ['display', 3.223826419473291, 463],
#  ['界面', 2.696367574053266, 464],
#  ['Map', 3.3155747560116855, 465],
#  ['sum', 3.487114856555011, 466],
#  ['open', 2.9638754418026445, 467],
#  ['resolve', 3.8198702289380977, 468],
#  ['高度', 2.859465098085628, 469],
#  ['子类', 3.2470981980576603, 470],
#  ['show', 3.0486546750083336, 471],
#  ['find', 3.2376876663902747, 472],
#  ['href', 3.3002080233716087, 473],
#  ['where', 3.322147830170534, 474],
#  ['form', 3.455336698386844, 475],
#  ['数据结构', 2.804391840513197, 476],
#  ['比特币', 4.077970094619131, 477],
#  ['username', 3.417477994187332, 478],
#  ['action', 3.4356683804052173, 479],
#  ['write', 3.0373175420154483, 480],
#  ['git', 3.600283290738735, 481],
#  ['Class', 3.3841848198122877, 482],
#  ['dependency', 3.9120951008825586, 483],
#  ['集群', 3.416159892063277, 484],
#  ['世界', 2.6815147654678317, 485],
#  ['api', 3.046832074260783, 486],
#  ['conf', 3.3727682053250545, 487],
#  ['开源', 2.66864511360472, 488],
#  ['客户', 3.046680340704616, 489],
#  ['阿里', 3.246727484429689, 490],
#  ['template', 3.5416011563824563, 491],
#  ['序列', 3.278356627013223, 492],
#  ['first', 3.1474827410103567, 493],
#  ['element', 3.5778397599698883, 494],
#  ['编程', 2.704739416445647, 495],
#  ['fmt', 4.263530934784298, 496],
#  ['npm', 3.4421815982647965, 497],
#  ['socket', 3.8519371047347604, 498],
#  ['byte', 3.537131320283836, 499],
#  ['原文', 2.203356815287797, 500],
#  ['format', 3.184577841076327, 501],
#  ['lang', 3.1604885826433953, 502],
#  ['父类', 3.441055598821427, 503],
#  ['dis', 3.9695928572496237, 504],
#  ['throw', 3.182837802356453, 505],
#  ['token', 3.836777643127388, 506],
#  ['label', 3.719551990017066, 507],
#  ['source', 3.1417933012991504, 508],
#  ['微服务', 3.7764480674878196, 509],
#  ['规范', 2.783884345163868, 510],
#  ['toString', 3.091518379440116, 511],
#  ['linux', 2.701726069352742, 512],
#  ['绘制', 3.504949118324133, 513],
#  ['中心', 2.9859040083515933, 514],
#  ['child', 3.8700913967812007, 515],
#  ['价值', 2.8745506348494216, 516],
#  ['struct', 3.6194685314600834, 517],
#  ['社区', 2.8549458837660358, 518],
#  ['成本', 2.7579746685046613, 519],
#  ['博客', 2.6556310898156745, 520],
#  ['port', 3.2196691608875967, 521],
#  ['None', 3.490892901190546, 522],
#  ['JSON', 3.2048089823240566, 523],
#  ['interface', 3.0526150762244306, 524],
#  ['nil', 3.8914022469437253, 525],
#  ['课程', 3.2584714911567336, 526],
#  ['transform', 3.8188845216133385, 527],
#  ['Server', 3.2301860302597873, 528],
#  ['put', 3.376770317038605, 529],
#  ['屏幕', 3.0757749812275277, 530],
#  ['ppend', 3.31537624484478, 531],
#  ['cache', 3.4503264396709286, 532],
#  ['端口', 3.05353124669621, 533],
#  ['深度学习', 3.5406061314247386, 534],
#  ['颜色', 3.096449591214315, 535],
#  ['dding', 3.43948132659705, 536],
#  ['感觉', 2.499649645316108, 537],
#  ['作用域', 3.5307099596170057, 538],
#  ['关键', 2.4660671377985515, 539],
#  ['join', 3.1954341900421386, 540],
#  ['loader', 4.188545127899736, 541],
#  ['query', 3.5112066598018066, 542],
#  ['教程', 2.809166258749475, 543],
#  ['utf', 2.9689160573477835, 544],
#  ['链表', 3.9244275023752198, 545],
#  ['新建', 2.66864511360472, 546],
#  ['googlevideo', 11.146993521197391, 547],
#  ['group', 3.4934986115361375, 548],
#  ['#include', 3.709787154326098, 549],
#  ['底层', 2.7014037486408458, 550],
#  ['后台', 2.7806232195157365, 551],
#  ['demo', 3.083773141954361, 552],
#  ['特点', 2.555899521941619, 553],
#  ['数据类型', 2.982625550565138, 554],
#  ['单位', 2.853068888908514, 555],
#  ['link', 3.2945544358398804, 556],
#  ['export', 3.275110180926938, 557],
#  ['次数', 2.8195091050091254, 558],
#  ['values', 3.277591808620301, 559],
#  ['字典', 3.441280697302963, 560],
#  ['blog', 2.8057025347729243, 561],
#  ['boot', 3.843150295919686, 562],
#  ['计算机', 2.932122378972449, 563],
#  ['互联网', 2.83228377839906, 564],
#  ['queue', 3.9413583447870266, 565],
#  ['lib', 3.2931945521917507, 566],
#  ['科技', 3.153035973623825, 567],
#  ['output', 3.43365563232552, 568],
#  ['callback', 3.6100963916312203, 569],
#  ['undefined', 3.3554707020466585, 570],
#  ['header', 3.3974555625161598, 571],
#  ['train', 4.576110558857806, 572],
#  ['File', 3.4403806072331937, 573],
#  ['用法', 2.6634605312737882, 574],
#  ['经验', 2.7074375995083053, 575],
#  ['react', 3.9092153292739473, 576],
#  ['make', 3.294165708915646, 577],
#  ['application', 3.110581832198767, 578],
#  ['合约', 4.311808935050089, 579],
#  ['temp', 3.969211105002193, 580],
#  ['post', 3.1518554354986925, 581],
#  ['row', 3.755578286522032, 582],
#  ['Array', 3.354644597084353, 583],
#  ['宽度', 3.343354320118761, 584],
#  ['thread', 3.7639361745183093, 585],
#  ['store', 3.926253986901254, 586],
#  ['task', 4.00456145508737, 587],
#  ['ctx', 4.547803525583459, 588],
#  ['UTF', 3.0568977380164313, 589],
#  ['个数', 2.893635675758654, 590],
#  ['props', 4.096437443583582, 591],
#  ['整体', 2.5829167438823024, 592],
#  ['ArrayList', 3.59528130584608, 593],
#  ['example', 3.4283080259989247, 594],
#  ['意义', 2.5131735178494337, 595],
#  ['答案', 2.762874684006495, 596],
#  ['分布式', 3.05322576326631, 597],
#  ['整数', 3.0974068344271672, 598],
#  ['成员', 3.167997150343276, 599],
#  ['lock', 3.8577243549296023, 600],
#  ['meta', 3.2677020361151197, 601],
#  ['master', 3.484995962295497, 602],
#  ['数据集', 3.5160469403069317, 603],
#  ['tch', 4.081807234266425, 604],
#  ['Google', 3.077025372137549, 605],
#  ['同学', 2.8196300020654292, 606],
#  ['Date', 3.43790952881078, 607],
#  ['center', 3.3901562600345483, 608],
#  ['数值', 2.94519624080045, 609],
#  ['加密', 3.4473775887192755, 610],
#  ['instance', 3.4949227750809087, 611],
#  ['细节', 2.6068653584986574, 612],
#  ['样本', 3.8492252386660106, 613],
#  ['SELECT', 3.804214331865545, 614],
#  ['商品', 3.669955048877694, 615],
#  ['手动', 2.6197509939281516, 616],
#  ['线程池', 4.0951378982414965, 617],
#  ['学生', 3.648400680479878, 618],
#  ['篇文章', 2.5785370358436115, 619],
#  ['cookie', 4.002586340876252, 620],
#  ['iOS', 3.3122054138091963, 621],
#  ['names', 3.210333365971964, 622],
#  ['Math', 3.4793674296123998, 623],
#  ['docker', 4.41180750756653, 624],
#  ['current', 3.6055757084902003, 625],
#  ['HashMap', 3.8536357632033407, 626],
#  ['关联', 2.8982027875009777, 627],
#  ['原生', 2.987046865618843, 628],
#  ['一个对象', 2.863373076585902, 629],
#  ['意思', 2.5767336088444606, 630],
#  ['render', 3.721337704777301, 631],
#  ['home', 3.510965259679934, 632],
#  ['人类', 3.4113416611036937, 633],
#  ['flex', 4.385999623610657, 634],
#  ['using', 3.1006042791976576, 635],
#  ['距离', 3.197372687433032, 636],
#  ['auto', 3.2996216850376014, 637],
#  ['命名', 2.9084565910256215, 638],
#  ['优势', 2.6992575947963746, 639],
#  ['背景', 2.838301604358493, 640],
#  ['神经网络', 3.827459772050497, 641],
#  ['主题', 2.971445925176363, 642],
#  ['random', 3.448510733316444, 643],
#  ['bind', 3.441280697302963, 644],
#  ['canvas', 4.41299656834872, 645],
#  ['处理器', 3.4198990364175486, 646],
#  ['one', 3.2386063619073475, 647],
#  ['Hello', 3.312007570302764, 648],
#  ['缺点', 2.833386381879832, 649],
#  ['you', 3.2509990110285143, 650],
#  ['protected', 3.3187563057226304, 651],
#  ['符号', 3.1555704009329664, 652],
#  ['red', 3.467510961532451, 653],
#  ['入门', 2.8241134994274857, 654],
#  ['消费者', 3.4918396468233923, 655],
#  ['process', 3.5213984490649364, 656],
#  ['概率', 3.43343224351637, 657],
#  ['plugin', 3.764869155459878, 658],
#  ['rams', 3.7491256600468046, 659],
#  ['案例', 2.984049646505047, 660],
#  ['级别', 2.9631773614950636, 661],
#  ['选择器', 4.096437443583582, 662],
#  ['insert', 3.469593090682583, 663],
#  ['tar', 3.868709703987985, 664],
#  ['腾讯', 3.420560339208099, 665],
#  ['env', 3.693431649554017, 666],
#  ['有点', 2.533853988733944, 667],
#  ['click', 3.480537430915869, 668],
#  ['百度', 3.0934243520628497, 669],
#  ['match', 3.720742112145043, 670],
#  ['重点', 2.6269045266691275, 671],
#  ['router', 4.136681653890161, 672],
#  ['dict', 3.875637338205788, 673],
#  ['double', 3.681624456950504, 674],
#  ['equals', 3.586652673411431, 675],
#  ['引擎', 3.273205418446284, 676],
#  ['工程', 3.135472588306349, 677],
#  ['Activity', 4.172514610172345, 678],
#  ['tmp', 3.806482273871185, 679],
#  ['delete', 3.255662763535502, 680],
#  ['sudo', 3.7583564948223347, 681],
#  ['机器人', 3.9799556442851705, 682],
#  ['are', 3.1798866675004462, 683],
#  ['原型', 3.68996143207501, 684],
#  ['编辑', 2.9424583883031112, 685],
#  ['constructor', 3.5793893470568228, 686],
#  ['option', 3.9939418862599103, 687],
#  ['synchronized', 3.876680635118366, 688],
#  ['Windows', 3.168853975003698, 689],
#  ['JVM', 3.4987304902954706, 690],
#  ['全球', 3.1712569971006657, 691],
#  ['alert', 3.691405892820167, 692],
#  ['servlet', 4.375630867120808, 693],
#  ['朋友', 2.7447623482508345, 694],
#  ['计划', 2.9758179792458974, 695],
#  ['程度', 2.689125795865968, 696],
#  ['C++', 3.375715575879754, 697],
#  ['remove', 3.210690827995431, 698],
#  ['pre', 3.6665652151231827, 699],
#  ['编译器', 3.3474451419414986, 700],
#  ['运行时', 3.017081767455689, 701],
#  ['base', 3.478666085340519, 702],
#  ['host', 3.3702487834591115, 703],
#  ['last', 3.479835265878243, 704],
#  ['标题', 3.1170722005934084, 705],
#  ['结点', 4.574011922200885, 706],
#  ['dir', 3.679908209389648, 707],
#  ['水平', 2.9265904212636613, 708],
#  ['实例化', 3.241183208538459, 709],
#  ['getName', 3.5614585387864297, 710],
#  ['生命周期', 3.239157984611415, 711],
#  ['角度', 2.819871840035169, 712],
#  ['article', 3.043801768911604, 713],
#  ['order', 3.5744905361770063, 714],
#  ['async', 3.7964773493633923, 715],
#  ['静态', 3.0398760504470004, 716],
#  ['core', 3.515561856620485, 717],
#  ['哈希', 3.835775136777762, 718],
#  ['align', 3.7068468405347024, 719],
#  ['handler', 3.8794680933692187, 720],
#  ['常量', 3.3978865970055923, 721],
#  ['load', 3.341926476938901, 722],
#  ['角色', 3.3285632491267343, 723],
#  ['优点', 2.861732387128442, 724],
#  ['split', 3.405242753067929, 725],
#  ['像素', 3.6905389660211814, 726],
#  ['jpg', 3.486643603011888, 727],
#  ['APP', 3.43387907104838, 728],
#  ['回调函数', 3.5391154479188827, 729],
#  ['价格', 3.3831222333771684, 730],
#  ['FROM', 3.8725139624235196, 731],
#  ['location', 3.606106494065295, 732],
#  ['流量', 3.470519874808234, 733],
#  ['区块', 4.377925761989147, 734],
#  ['控件', 3.7342295037708273, 735],
#  ['bool', 3.5112066598018066, 736],
#  ['implements', 3.170398111880814, 737],
#  ['False', 3.5668041032528497, 738],
#  ['save', 3.413528888572337, 739],
#  ['items', 3.6665652151231827, 740],
#  ['人员', 3.042441121638413, 741],
#  ['分支', 3.6202759598446845, 742],
#  ['jQuery', 3.8384507236582, 743],
#  ['std', 3.86767468578277, 744],
#  ['Set', 3.482881548257424, 745],
#  ['bar', 3.9247925324942576, 746],
#  ['Test', 3.6316489500169546, 747],
#  ['闭包', 4.0428494282098635, 748],
#  ['Service', 3.6742085644357507, 749],
#  ['硬件', 3.1560780581060652, 750],
#  ['办法', 2.6767871210054897, 751],
#  ['本质', 2.768947461191311, 752],
#  ['电脑', 3.06629181649444, 753],
#  ['小时', 3.014727786671769, 754],
#  ['buffer', 4.052758675272635, 755],
#  ['磁盘', 3.517503604803396, 756],
#  ['分区', 4.1861715212785615, 757],
#  ['xxx', 3.352994431693395, 758],
#  ['bottom', 3.6870787549562856, 759],
#  ['sleep', 3.5339154857251747, 760],
#  ['jar', 3.798084291698582, 761],
#  ['GET', 3.4473775887192755, 762],
#  ['矩阵', 3.9117346755768008, 763],
#  ['苹果', 3.6079664653733956, 764],
#  ['信号', 3.60424997582884, 765],
#  ['wait', 3.7418018555682786, 766],
#  ['channel', 4.391224599213135, 767],
#  ['proxy', 3.992768865597547, 768],
#  ['Student', 4.7609563071476675, 769],
#  ['address', 3.7676733324025653, 770],
#  ['大数据', 3.40394066955063, 771],
#  ['实体', 3.4289749149866284, 772],
#  ['tcp', 4.146203376248064, 773],
#  ['login', 3.793271190797759, 774],
#  ['none', 3.3890873128456436, 775],
#  ['专业', 3.1201699449797613, 776],
#  ['爬虫', 3.8428138787592383, 777],
#  ['setTimeout', 3.783080019791571, 778],
#  ['资料', 2.861480212117649, 779],
#  ['can', 3.236036138351802, 780],
#  ['入口', 3.1640651852809065, 781],
#  ['container', 3.8058337654178476, 782],
#  ['原则', 3.0951746906432263, 783],
#  ['内核', 3.552109133980871, 784],
#  ['charset', 3.1798866675004462, 785],
#  ['单词', 3.723126614020025, 786],
#  ['now', 3.6637491051235407, 787],
#  ['Type', 3.383547132470028, 788],
#  ['column', 4.0407973035414155, 789],
#  ['encoding', 3.3736094251433264, 790],
#  ['空格', 3.2893193293611143, 791],
#  ['score', 4.397647978962895, 792],
#  ['replace', 3.581200238768876, 793],
#  ['filename', 3.7586656616202836, 794],
#  ['await', 4.25283019573472, 795],
#  ['机会', 2.9356463728606053, 796],
#  ['ref', 3.781496989541718, 797],
#  ['工程师', 3.2452460026772463, 798],
#  ['send', 3.6940111917319305, 799],
#  ['交流', 2.8374396945593974, 800],
#  ['二进制', 3.362936518557462, 801],
#  ['美国', 3.4399308658269176, 802],
#  ['component', 3.9931597196185478, 803],
#  ['sort', 3.5840525679424267, 804],
#  ['时代', 3.1300157744351282, 805],
#  ['中间件', 3.8482101819048586, 806],
#  ['镜像', 3.8878773931002897, 807],
#  ['思想', 2.9480790762104014, 808],
#  ['keys', 3.6008112738555407, 809],
#  ['人们', 3.1083201187952283, 810],
#  ['容量', 3.68047996469396, 811],
#  ['IOException', 3.877376771589221, 812],
#  ['TCP', 3.771737743187636, 813],
#  ['终端', 3.303537116821275, 814],
#  ['mode', 3.5458410929001007, 815],
#  ['深度', 3.1516869009065687, 816],
#  ['printStackTrace', 3.6648745976452752, 817],
#  ['before', 3.5463410929105175, 818],
#  ['用户名', 3.3033409807021803, 819],
#  ['动作', 3.2221976072409553, 820],
#  ['sys', 3.957071350451583, 821],
#  ['promise', 4.427980366812131, 822],
#  ['内置', 2.996237050921839, 823],
#  ['tag', 3.9167924898271815, 824],
#  ['谷歌', 3.502074176238534, 825],
#  ['flag', 3.958580784700437, 826],
#  ['评论', 3.2376876663902747, 827],
#  ['schema', 4.432216379197737, 828],
#  ['plt', 4.918482517606208, 829],
#  ['表单', 3.668541221411872, 830],
#  ['理论', 3.0272972682401407, 831],
#  ['装饰', 4.22287288812899, 832],
#  ['官网', 2.950418902479199, 833],
#  ['嵌套', 3.2554757952260855, 834],
#  ['Context', 3.8970679844794027, 835],
#  ['copy', 3.5138659143605713, 836],
#  ['小米', 4.263018770880657, 837],
#  ['entry', 3.9896475208861952, 838],
#  ['域名', 3.6069032010520656, 839],
#  ['调度', 3.6722213387995204, 840],
#  ['备份', 3.852955953523863, 841],
#  ['search', 3.693431649554017, 842],
#  ['scope', 4.061510554431527, 843],
#  ['以太坊', 4.429793603936312, 844],
#  ['person', 4.38253141204173, 845],
#  ['req', 4.368777613570239, 846],
#  ['typeof', 3.712440848939564, 847],
#  ['will', 3.4314239866771823, 848],
#  ['序列化', 3.8016286807805217, 849],
#  ['word', 4.089525968986926, 850],
#  ['订单', 4.00298105175566, 851],
#  ['conn', 4.606685283135897, 852],
#  ['POST', 3.6186617544901436, 853],
#  ['区分', 2.8868885371483004, 854],
#  ['Error', 3.4207808706898617, 855],
#  ['reject', 4.487058781241903, 856],
#  ['via', 3.8522766056716486, 857],
#  ['历史', 3.117235000756568, 858],
#  ['timeout', 3.692852443050712, 859],
#  ['h2', 3.8471961544392297, 860],
#  ['权重', 3.8492252386660106, 861],
#  ['文件名', 3.298450038740711, 862],
#  ['证明', 3.2094402695475033, 863],
#  ['老师', 3.4399308658269176, 864],
#  ['Println', 4.586670319072808, 865],
#  ['world', 3.5253085224727796, 866],
#  ['btn', 4.332450623937432, 867],
#  ['整理', 2.928745594511645, 868],
#  ['向量', 4.093407794003714, 869],
#  ['bytes', 3.871821201744619, 870],
#  ['tree', 3.883313579667225, 871],
#  ['rse', 3.5806825064249272, 872],
#  ['files', 3.606371992540238, 873],
#  ['properties', 3.6856405266053938, 874],
#  ['孩子', 4.1187920891393865, 875],
#  ['yum', 3.9865358886594993, 876],
#  ['tab', 4.172514610172345, 877],
#  ['命令行', 3.216967186803866, 878],
#  ['论文', 3.8391207404336845, 879],
#  ['来源', 2.9256489915659945, 880],
#  ['账户', 3.7811806839879183, 881],
#  ['知识点', 3.1359701420109496, 882],
#  ['ret', 4.470539981230926, 883],
#  ['printf', 3.9657818770274544, 884],
#  ['after', 3.486879202023462, 885],
#  ['Name', 3.8110336471375996, 886],
#  ['success', 3.6640303595199946, 887],
#  ['Session', 4.12590955690825, 888],
#  ['ES6', 3.7225299552911073, 889],
#  ['shape', 4.359148538887811, 890],
#  ['源代码', 3.1412928425348476, 891],
#  ['公众号', 3.0615067490945447, 892],
#  ['total', 3.9638818194541092, 893],
#  ['system', 3.562474540905832, 894],
#  ['华为', 4.200498413899323, 895],
#  ['field', 4.1430193844747105, 896],
#  ['尺寸', 3.57551987234612, 897],
#  ['金融', 3.790713644646642, 898],
#  ['风险', 3.3484704675721844, 899],
#  ['表格', 3.5056691471563926, 900],
#  ['student', 4.70604698056447, 901],
#  ['中文', 3.2432125423222447, 902],
#  ['风格', 3.352994431693395, 903],
#  ['commit', 3.8892858440373477, 904],
#  ['标识', 3.1982550663837803, 905],
#  ['project', 3.7884811449153823, 906],
#  ['baidu', 3.736343988775543, 907],
#  ['城市', 3.7375542763665464, 908],
#  ['运算符', 3.8492252386660106, 909],
#  ['inline', 3.6940111917319305, 910],
#  ['yield', 4.379650395931998, 911],
#  ['全面', 3.0480467722540507, 912],
#  ['images', 3.949932488647375, 913],
#  ['拷贝', 3.4045914993816084, 914],
#  ['fun', 4.475593687501694, 915],
#  ['connection', 4.018096693571716, 916],
#  ['技巧', 3.1956102618799034, 917],
#  ['Docker', 4.169712179566643, 918],
#  ['admin', 3.984208502038722, 919],
#  ['cout', 4.675420322985478, 920],
#  ['仓库', 3.6456351919916945, 921],
#  ['字体', 3.854996770558716, 922],
#  ['author', 3.7402827910197503, 923],
#  ['maven', 4.181441143489037, 924],
#  ['debug', 3.585871931667153, 925],
#  ['stack', 4.1308323683714665, 926],
#  ['属性值', 3.491602876371238, 927],
#  ['include', 3.6308322901103987, 928],
#  ['offset', 4.045729496030734, 929],
#  ['构造方法', 3.8218445632418154, 930],
#  ['This', 3.43365563232552, 931],
#  ['Data', 3.583014415759906, 932],
#  ['iPhone', 3.899912936611634, 933],
#  ['类别', 3.7177694583507828, 934],
#  ['设计模式', 3.584312274475506, 935],
#  ['联系', 2.92055378075742, 936],
#  ['体系', 3.343150217658618, 937],
#  ['jianshu', 2.7861033241765543, 938],
#  ['2d', 3.6055757084902003, 939],
#  ['中断', 3.7059664296194326, 940],
#  ['connect', 3.670521140033485, 941],
#  ['arguments', 3.8836639037205543, 942],
#  ['开发人员', 3.3002080233716087, 943],
#  ['Log', 4.128144194709667, 944],
#  ['Bean', 4.256893177453974, 945],
#  ['Model', 3.8465207069295917, 946],
#  ['Component', 3.9795699162186713, 947],
#  ['solid', 3.958580784700437, 948],
#  ['exports', 4.119679007157615, 949],
#  ['迭代器', 4.275902226586845, 950],
#  ['logger', 4.438299123013506, 951],
#  ['support', 3.7777079101741404, 952],
#  ['dom', 3.8826132995265628, 953],
#  ['一致性', 3.617855627884619, 954],
#  ['明白', 2.9626192479044637, 955],
#  ['XML', 3.7654916266906837, 956],
#  ['users', 4.085659154286953, 957],
#  ['global', 3.6191995334759466, 958],
#  ['员工', 3.921876015662062, 959],
#  ['两者', 2.9932122016583182, 960],
#  ['专门', 2.919083683599908, 961],
#  ['cat', 3.8444970974700645, 962],
#  ['Chrome', 3.5786142533608682, 963],
#  ['规定', 3.2080129722489987, 964],
#  ['省略', 3.2753008568737454, 965],
#  ['DEFAULT', 4.0758446953068175, 966],
#  ['price', 4.609577548348043, 967],
#  ['worker', 4.525587869433256, 968],
#  ['grid', 4.959756619571331, 969],
#  ['习惯', 3.161509164463568, 970],
#  ['pop', 3.730615042004463, 971],
#  ['execute', 3.8580658266761336, 972],
#  ['into', 3.5662937689728276, 973],
#  ['INSERT', 4.429793603936312, 974],
#  ['前言', 2.769292308599752, 975],
#  ['volatile', 4.477495431339511, 976],
#  ['经历', 3.153204735754004, 977],
#  ['维度', 3.675061442952268, 978],
#  ['笔记', 3.1424609694928733, 979],
#  ['Cookie', 4.527587203654738, 980],
#  ['单元', 3.6316489500169546, 981],
#  ['command', 3.8218445632418154, 982],
#  ['abc', 3.957071350451583, 983],
#  ['xmlns', 4.09817280193665, 984],
#  ['has', 3.4341025597072607, 985],
#  ['读者', 3.355057564259332, 986],
#  ['基本上', 2.9986924576584775, 987],
#  ['校验', 3.6742085644357507, 988],
#  ['质量', 3.4210014508164863, 989],
#  ['Content', 3.666283246983714, 990],
#  ['level', 3.9310185185459243, 991],
#  ['国家', 3.489474461236412, 992],
#  ['物理', 3.5066299927743945, 993],
#  ['stop', 3.6058410660610822, 994],
#  ['上线', 3.273776466334649, 995],
#  ['Boot', 4.288953834461187, 996],
#  ['##', 4.150312033020852, 997],
#  ['finally', 3.717472678410928, 998],
#  ['层面', 3.2243699469801044, 999],
#  ...]

# %% [markdown]
# ### 计算tfidf

# %%
cv_result = cv_model.transform(words_df)
tfidf_result = idf_model.transform(cv_result)

# %%
tfidf_result.show()
# Out:
# +----------+----------+--------------------+--------------------+--------------------+
# |article_id|channel_id|               words|       countFeatures|         idfFeatures|
# +----------+----------+--------------------+--------------------+--------------------+
# |         1|        17|[Vue, props, 用法, ...|(1234544,[1,2,3,5...|(1234544,[1,2,3,5...|
# |         2|        17|[vue, 响应式, 原理, mo...|(1234544,[1,2,3,4...|(1234544,[1,2,3,4...|
# |         3|        17|[JavaScript, 浅拷贝,...|(1234544,[0,1,2,4...|(1234544,[0,1,2,4...|
# |         4|        17|[vue2, vuex, elem...|(1234544,[1,2,4,5...|(1234544,[1,2,4,5...|
# |         5|        17|[immutability, Re...|(1234544,[1,2,4,5...|(1234544,[1,2,4,5...|
# |         6|        17|[node, npm, cnpm,...|(1234544,[0,1,2,3...|(1234544,[0,1,2,3...|
# |         7|        17|[Web, 工程师, 以太坊, 入...|(1234544,[1,2,3,4...|(1234544,[1,2,3,4...|
# |         8|        17|[Web, pa, api, we...|(1234544,[1,2,3,1...|(1234544,[1,2,3,1...|
# |         9|        17|[vue, 中用, 数据驱动, 视...|(1234544,[1,3,4,5...|(1234544,[1,3,4,5...|
# |        10|        17|[程序, WebSocket, 长...|(1234544,[1,3,7,1...|(1234544,[1,3,7,1...|
# |        11|        17|[flux, 架构, flux, ...|(1234544,[1,4,5,6...|(1234544,[1,4,5,6...|
# |        12|        17|[合格, TypeScript, ...|(1234544,[1,2,3,4...|(1234544,[1,2,3,4...|
# |        13|        17|[专属, 插件, Easy, Sl...|(1234544,[1,2,4,6...|(1234544,[1,2,4,6...|
# |        14|        17|[前后端分离, vue, 网站前台...|(1234544,[1,2,3,6...|(1234544,[1,2,3,6...|
# |        15|        17|[ajax, 页面, 重复提交, ...|(1234544,[1,2,3,4...|(1234544,[1,2,3,4...|
# |        17|        17|[JSsearch, 购物网站, ...|(1234544,[1,2,3,4...|(1234544,[1,2,3,4...|
# |        18|        17|[web, pa, react, ...|(1234544,[1,2,3,1...|(1234544,[1,2,3,1...|
# |        19|        17|[合格, 事顶, 项目, 自我介绍...|(1234544,[1,2,3,4...|(1234544,[1,2,3,4...|
# |        20|        17|[jQuery, 用法, jque...|(1234544,[1,2,3,4...|(1234544,[1,2,3,4...|
# |        21|        17|[Bootstrap, Modal...|(1234544,[1,2,3,4...|(1234544,[1,2,3,4...|
# +----------+----------+--------------------+--------------------+--------------------+

# %%
tfidf_result.rdd.take(1)
# Out:
# [Row(article_id=1, channel_id=17, words=['Vue', 'props', '用法', '小结', 'Vue', 'props', '用法', '组件', '选项', 'props', 'Vue', '选项', '父子', '组件', '关系', 'props', 'events', '组件', 'props', '传递数据', '组件', '组件', 'events', '组件', '发送消息', '父子', '组件', '组件', 'pa', 'rent', 'child', '组件', '环境', '书写', '组件', '可维护性', '定义', '父子', '组件', 'Vue', '对象', 'var', 'childNode', 'template', 'div', 'childNode', 'div', 'var', 'pa', 'rentNode', 'template', 'div', 'child', 'child', 'child', 'child', 'div', 'components', 'child', 'childNode', '全栈', '交流', 'Ian', '人员', '技术', '瓶颈', '思维能力', 'Vue', 'components', 'pa', 'rent', 'pa', 'rentNode', 'div', 'pa', 'rent', 'pa', 'rent', 'div', 'childNode', '定义', 'template', 'div', '内容', 'childNode', '字符串', 'pa', 'rentNode', 'template', '定义', 'div', 'class', 'pa', 'rent', 'child', '组件', '静态', 'props', '组件', '实例', '作用域', '组件', '模板', '饮用', '组件', '数据', '组件', '组件', '数据', '组件', 'props', '选项', '组件', '向子', '组件', '传递数据', '方式', '动态', '静态', '静态', '方式', '组件', 'props', '声明', '数据', '上例', '代码', 'childNode', 'props', '选项', 'forChildMsg', '数据', '组件', '占位符', '特性', '方式', '传递数据', 'var', 'childNode', 'template', 'div', 'forChildMsg', 'div', 'props', 'child', 'msg', 'var', 'pa', 'rentNode', 'template', 'div', 'pa', 'rentNode', 'child', 'child', 'msg', 'aaa', 'child', 'child', 'child', 'msg', 'bbb', 'child', 'div', 'components', 'child', 'childNode', '命名规范', 'props', '声明', '属性', '组件', 'template', '模板', '属性', '中划线', '组件', 'props', '属性', '声明', '驼峰', '中划线', '组件', '模板', '组件', '驼峰', 'Vue', '驼峰', '命名', 'forChildMsg', 'child', 'msg', '动态', 'props', '模板', '动态', '组件', '数据', '组件', '模板', 'props', 'Html', '标签', '特性', 'bind', '静态', 'props', '代码', '组件', 'var', 'pa', 'rentNode', 'template', 'div', 'pa', 'rentNode', 'child', 'child', 'msg', 'childMsg1', 'child', 'child', 'child', 'msg', 'childMsg2', 'child', 'div', 'components', 'child', 'childNode', 'data', 'function', 'return', 'childMsg1', 'Dynamic', 'props', 'msg', 'child', 'childMsg2', 'Dynamic', 'props', 'msg', 'child', '组件', 'data', 'return', '数据', 'childMsg1', 'childMsg2', '组件', 'props', 'props', '参数', '数据', '规格', '数据', '规格', 'Vue', '警告', '种类', 'type', 'String', 'Number', 'Boolean', 'Function', 'Object', 'Array', 'SymbolVue', 'component', 'props', '基础', '类型', 'ul', '类型', '都行', 'propA', 'Number', '多种类型', 'propB', 'String', 'Number', 'String', 'propC', 'type', 'String', 'required', 'true', '数字', 'propD', 'type', 'Number', 'defa', 'ul', '数组', '工厂', '函数返回', '对象', 'propE', 'type', 'Object', 'defa', 'ul', 'function', 'console', 'log', 'propE', 'defa', 'ul', 'invoked', 'return', 'message', 'propE', '函数', 'propF', 'isValid', 'function', 'return', 'childNode', 'template', 'div', 'forChildMsg', 'div', 'props', 'child', 'msg', 'Number', 'pa', 'rentNode', 'template', 'div', 'class', 'pa', 'rent', 'child', 'child', 'msg', 'msg', 'child', 'div', 'components', 'child', 'childNode', 'data', 'return', '字符串', '时会', 'msg', 'props', '定义', '数据', '函数', '函数返回', 'false', '警告', '例子', 'childNode', 'child', 'msg', '一个对象', 'validator', '函数', '命名', 'validator', '自定义函数', '生效', 'childNode', 'template', 'div', 'forChildMsg', 'div', 'props', 'child', 'msg', 'validator', 'function', 'return', 'child', 'msg', 'validator', '函数', '警告', '单向', '数据流', 'props', '单向', '组件', '属性', '传导', '组件', '组件', '组件', '状态', '组件', 'props', 'Vue', '警告', 'childNode', 'template', 'div', 'class', 'child', 'div', 'pa', '组件', '数据', 'pa', 'input', 'model', 'forChildMsg', 'div', 'forChildMsg', 'div', 'props', 'child', 'msg', 'String', 'pa', 'rentNode', 'template', 'div', 'class', 'pa', 'rent', 'div', 'pa', '组件', '数据', 'pa', 'input', 'model', 'msg', 'div', 'msg', 'child', 'child', 'msg', 'msg', 'child', 'div', 'components', 'child', 'childNode', 'data', 'return', 'msg', 'defa', 'ul', 'string', '组件', '和子', '组件', '输入框', '组件', '数据', '和子', '组件', '数据', '组件', '输入框', '数据', '组件', '数据', 'props', '向子', '组件', '传递数据', '组件', '输入框', '浏览器', '错误', '警告', 'Vue', 'warn', 'Avoid', 'mutating', 'prop', 'directly', 'overwritten', 'pa', 'rent', 'component', 'renders', 'Instead', 'data', 'computed', 'p ...

# %%
def func(partition):
    TOPK = 20
    for row in partition:
        # 找到索引与IDF值并进行排序
        _ = list(zip(row.idfFeatures.indices, row.idfFeatures.values))
        _ = sorted(_, key=lambda x: x[1], reverse=True)
        result = _[:TOPK]
        for word_index, tfidf in result:
            yield row.article_id, row.channel_id, int(word_index), round(float(tfidf), 4)

_keywordsByTFIDF = tfidf_result.rdd.mapPartitions(func).toDF(["article_id", "channel_id", "index", "tfidf"])

# %%
_keywordsByTFIDF.show()
# Out:
# +----------+----------+------+--------+
# |article_id|channel_id| index|   tfidf|
# +----------+----------+------+--------+
# |         1|        17| 96675|256.3809|
# |         1|        17|115370|200.6459|
# |         1|        17|   515|174.1541|
# |         1|        17| 20134|141.6573|
# |         1|        17|   591|126.9896|
# |         1|        17|    62|125.4149|
# |         1|        17|    45|101.2453|
# |         1|        17|   391| 85.5727|
# |         1|        17|   491| 56.6656|
# |         1|        17|  5650| 51.6382|
# |         1|        17|  1465| 37.7835|
# |         1|        17|415962|  33.441|
# |         1|        17|426351|  33.441|
# |         1|        17|   347| 31.9532|
# |         1|        17|151480| 28.0657|
# |         1|        17|   314| 26.1522|
# |         1|        17|  1353| 25.2814|
# |         1|        17|  5808|  23.998|
# |         1|        17|     5| 23.4382|
# |         1|        17|  5371| 20.4942|
# +----------+----------+------+--------+
# only showing top 20 rows

# %%
keywordsIndex = ktt.spark.sql("select keyword, index idx from idf_keywords_values")

# %%
keywordsByTFIDF = _keywordsByTFIDF.join(keywordsIndex, keywordsIndex.idx == _keywordsByTFIDF.index).select(["article_id", "channel_id", "keyword", "tfidf"])

# %%
keywordsByTFIDF.show()
# Out:
# +----------+----------+---------+--------+
# |article_id|channel_id|  keyword|   tfidf|
# +----------+----------+---------+--------+
# |         3|        17|      var| 22.4813|
# |         7|        17|      var| 41.2158|
# |        13|        17|      var| 74.9377|
# |        21|        17|      var| 14.9875|
# |        11|        17|  Actions| 98.2025|
# |        13|        17|barNumber|  55.735|
# |        18|        17|   loader|125.6564|
# |         7|        17|     uint| 29.6332|
# |        17|        17| document| 16.8342|
# |         9|        17|  caidan2| 10.7415|
# |         3|        17|       &#| 41.1171|
# |        12|        17|    Watch| 42.4374|
# |        20|        17|  closest| 33.8248|
# |         4|        17|      cmd| 15.7818|
# |        10|        17|       石头| 44.6937|
# |        18|        17|      mod| 42.2456|
# |         2|        17|     元素节点|  83.279|
# |        20|        17|     提交表单|  27.922|
# |         1|        17|      Vue| 31.9532|
# |        12|        17|      Vue| 46.1546|
# +----------+----------+---------+--------+
# only showing top 20 rows

# %% [markdown]
# ### 计算textrank值

# %%
# 分词
def textrank(partition):
    import os

    import jieba
    import jieba.analyse
    import jieba.posseg as pseg
    import codecs

    abspath = "/root/words"

    # 结巴加载用户词典
    userDict_path = os.path.join(abspath, "ITKeywords.txt")
    jieba.load_userdict(userDict_path)

    # 停用词文本
    stopwords_path = os.path.join(abspath, "stopwords.txt")

    def get_stopwords_list():
        """返回stopwords列表"""
        stopwords_list = [i.strip()
                          for i in codecs.open(stopwords_path).readlines()]
        return stopwords_list

    # 所有的停用词列表
    stopwords_list = get_stopwords_list()

    class TextRank(jieba.analyse.TextRank):
        def __init__(self, window=20, word_min_len=2):
            super(TextRank, self).__init__()
            self.span = window  # 窗口大小
            self.word_min_len = word_min_len  # 单词的最小长度
            # 要保留的词性，根据jieba github ，具体参见https://github.com/baidu/lac
            self.pos_filt = frozenset(
                ('n', 'x', 'eng', 'f', 's', 't', 'nr', 'ns', 'nt', "nw", "nz", "PER", "LOC", "ORG"))

        def pairfilter(self, wp):
            """过滤条件，返回True或者False"""

            if wp.flag == "eng":
                if len(wp.word) <= 2:
                    return False

            if wp.flag in self.pos_filt and len(wp.word.strip()) >= self.word_min_len \
                    and wp.word.lower() not in stopwords_list:
                return True
    # TextRank过滤窗口大小为5，单词最小为2
    textrank_model = TextRank(window=5, word_min_len=2)
    allowPOS = ('n', "x", 'eng', 'nr', 'ns', 'nt', "nw", "nz", "c")

    import re
    
    for row in partition:
        sentence = re.sub("<.*?>", "", row.sentence)    # 替换掉标签数据
        tags = textrank_model.textrank(sentence, topK=20, withWeight=True, allowPOS=allowPOS, withFlag=False)
        for tag in tags:
            yield row.article_id, row.channel_id, tag[0], tag[1]

# %%
# 计算textrank
textrank_keywords_df = article_dataframe.rdd.mapPartitions(textrank).toDF(
["article_id", "channel_id", "keyword", "textrank"])

# textrank_keywords_df.write.insertInto("textrank_keywords_values")

# %%
textrank_keywords_df.show()
# Out:
# +----------+----------+-----------+-------------------+
# |article_id|channel_id|    keyword|           textrank|
# +----------+----------+-----------+-------------------+
# |         1|        17|         组件|                1.0|
# |         1|        17|      props| 0.5014665932761055|
# |         1|        17|        msg| 0.4456533603873207|
# |         1|        17|         数据|0.44060755114598205|
# |         1|        17|      child|0.33105197799128705|
# |         1|        17|         pa|0.23957543716597018|
# |         1|        17|        Vue| 0.2235228074555735|
# |         1|        17|  childNode|0.20705374199882054|
# |         1|        17|         ul| 0.1826491258545327|
# |         1|        17|forChildMsg|0.16026445493034286|
# |         1|        17|     String|0.15910269591934798|
# |         1|        17|       defa|0.15017376805500693|
# |         1|        17|         定义|0.14735936484781245|
# |         1|        17|      class|0.13948100302879202|
# |         1|        17|       rent|0.13237113947110707|
# |         1|        17|  validator|0.12867040029024143|
# |         1|        17|        var|0.12856105775268248|
# |         1|        17|       prop| 0.1278471840413465|
# |         1|        17|       传递数据|0.12715769832700669|
# |         1|        17|         属性| 0.1259038258484597|
# +----------+----------+-----------+-------------------+
# only showing top 20 rows

# %% [markdown]
# ### 文章画像构建

# %%
idf = ktt.spark.sql("select * from idf_keywords_values")

# %%
idf = idf.withColumnRenamed("keyword", "keyword1")

# %%
result = textrank_keywords_df.join(idf,textrank_keywords_df.keyword==idf.keyword1)

# %%
result.show()
# Out:
# +----------+----------+----------+-------------------+----------+------------------+------+
# |article_id|channel_id|   keyword|           textrank|  keyword1|               idf| index|
# +----------+----------+----------+-------------------+----------+------------------+------+
# |         2|        17|     input|0.29571012149785497|     input|2.5936612831652797|   139|
# |         1|        17| childNode|0.20705374199882054| childNode| 7.869848788205214| 20134|
# |        12|        17|    import| 0.6365577601955468|    import|1.9502451027406746|    44|
# |         3|        17|       amp|0.23615437035522693|       amp|1.5313880611157102|    18|
# |        13|        17|       amp| 0.2758702473634155|       amp|1.5313880611157102|    18|
# |        20|        17|  dragsort| 0.4264886869985381|  dragsort|10.741528413089226|153844|
# |         4|        17|        文章| 0.2816273109396151|        文章|1.5470125914600148|   107|
# |        20|        17|   indexOf| 0.2924464165952302|   indexOf| 4.096871000928331|  1412|
# |         2|        17|   textReg| 0.2954111626422379|   textReg|10.741528413089226| 95140|
# |        11|        17|        事件|0.34170640200171337|        事件|2.2787914074690474|   106|
# |        20|        17|        事件| 0.9720908674713441|        事件|2.2787914074690474|   106|
# |        21|        17|        感觉| 0.3432295815919894|        感觉| 2.499649645316108|   537|
# |         5|        17|       API|0.33174637943754814|       API|2.2407356430407694|   177|
# |         2|        17|  fragment| 0.6620222888230497|  fragment| 5.377111244836666|  2540|
# |         4|        17|        文件|0.35515785136161476|        文件|1.2163286406564702|    17|
# |         6|        17|        文件|0.13073439289184158|        文件|1.2163286406564702|    17|
# |        18|        17|        文件| 0.5104276528932955|        文件|1.2163286406564702|    17|
# |         8|        17|production|0.25755142033548006|production|4.6965230990532145|  2555|
# |         1|        17|      传递数据|0.12715769832700669|      传递数据| 5.123545928236358|  5371|
# |         4|        17|       文件夹|0.49528203729977055|       文件夹|2.7398384349900904|   404|
# +----------+----------+----------+-------------------+----------+------------------+------+
# only showing top 20 rows

# %%
keywords_res = result.withColumn("weights", result.textrank * result.idf).select(["article_id", "channel_id", "keyword", "weights"])

# %%
keywords_res.show()
# Out:
# +----------+----------+----------+-------------------+
# |article_id|channel_id|   keyword|            weights|
# +----------+----------+----------+-------------------+
# |         2|        17|     input| 0.7669718931690873|
# |         1|        17| childNode| 1.6294816405627728|
# |        12|        17|    import|  1.241443654432938|
# |         3|        17|       amp| 0.3616439833422923|
# |        13|        17|       amp| 0.4224644032293722|
# |        20|        17|  dragsort|  4.581140349255914|
# |         4|        17|        文章|0.43568099612260935|
# |        20|        17|   indexOf| 1.1981152434744045|
# |         2|        17|   textReg| 3.1731673970653205|
# |        11|        17|        事件| 0.7786776127586685|
# |        20|        17|        事件| 2.2151923160728315|
# |        21|        17|        感觉| 0.8579537018884125|
# |         5|        17|       API| 0.7433559368554415|
# |         2|        17|  fragment| 3.5597674935629273|
# |         4|        17|        文件|0.43198866656514556|
# |         6|        17|        文件|0.15901598639318257|
# |        18|        17|        文件| 0.6208477731971748|
# |         8|        17|production|  1.209596194799546|
# |         1|        17|      传递数据| 0.6514983075072422|
# |         4|        17|       文件夹|  1.356992761954107|
# +----------+----------+----------+-------------------+
# only showing top 20 rows

# %%
keywords_res.registerTempTable("temptable")
merge_keywords = ktt.spark.sql("select article_id, min(channel_id) channel_id, collect_list(keyword) keywords, collect_list(weights) weights from temptable group by article_id")

# 合并关键词权重合并成字典
def _func(row):
    return row.article_id, row.channel_id, dict(zip(row.keywords, row.weights))

keywords_info = merge_keywords.rdd.map(_func).toDF(["article_id", "channel_id", "keywords"])

# %%
topic_sql = """
                select t.article_id article_id2, collect_set(t.keyword) topics from tfidf_keywords_values t
                inner join 
                textrank_keywords_values r
                where t.keyword=r.keyword
                group by article_id2
                """
article_topics = ktt.spark.sql(topic_sql)

# %%
article_topics.show()
# Out:
# +-----------+--------------------+
# |article_id2|              topics|
# +-----------+--------------------+
# |        148|[transform, solid...|
# |        463|[clone, 按钮, 空格键, ...|
# |        471|[font, DOCTYPE, m...|
# |        496|[lock, 线程, 容器, 元素...|
# |        833|[modal, close, bu...|
# |       1088|[外边距, 宽度, 内边距, 像素...|
# |       1238|[内存, 服务员, 语言, 软件,...|
# |       1342|[速度, 距离, canvas, ...|
# |       1580|[filename, requir...|
# |       1591|[内容, keywords, li...|
# |       1645|[圆角, solid, width...|
# |       1829|[mirrors, https, ...|
# |       1959|[GNU, 软件, openjdk...|
# |       2122|[宽度, 样式, CSS+DIV,...|
# |       2142|[tuple, File, cod...|
# |       2366|[weights, &#, ste...|
# |       2659|[语言, pic, head, 结...|
# |       2866|[和子, 企业开发, class,...|
# |       3175|[stretch, transfo...|
# |       3749|[entry, ble, comp...|
# +-----------+--------------------+
# only showing top 20 rows

# %%
article_profile = keywords_info.join(article_topics, keywords_info.article_id==article_topics.article_id2).select(["article_id", "channel_id", "keywords", "topics"])
